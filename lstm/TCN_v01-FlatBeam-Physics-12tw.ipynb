# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import scipy.io as sio
from matplotlib import rc

def set_style_sns():
    sns.set_context('paper')
    sns.set(font = 'serif')
    sns.set(font_scale = 1.3)
    
    sns.set_style('white', {
        'font.family': 'serif',
        'font.serif': ['Time', 'Palatino', 'serif'],
        'lines.markersize': 10
    })
    
    
plt.rcParams.update({'font.size':16})
set_style_sns()

plt.rcParams.update({'text.usetex': False})

# %%
data = sio.matlab.loadmat('../data/FlatBeam_NLResponse_RandVibe.mat')['out']
y = data[0]['def'][0].T[:, :, np.newaxis][:,10,:]
yv = data[0]['vel'][0].T[:, :, np.newaxis][:,10,:]
ya = data[0]['acc'][0].T[:, :, np.newaxis][:,10,:]
u = data[0]['fext'][0].T[:, :, np.newaxis][:,10,:]
t = data[0]['t'][0][0]

print(y.shape, u.shape, t.shape)
# Out:
# (10001, 1) (10001, 1) (10001,)

# %%
plt.figure(figsize=(10,12))
plt.subplot(4,1,1)
plt.plot(t,u)
plt.xlabel('time')
plt.ylabel('force')

plt.subplot(4,1,2)
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('displacement')

plt.subplot(4,1,3)
plt.plot(t,yv)
plt.xlabel('time')
plt.ylabel('velocity')

plt.subplot(4,1,4)
plt.plot(t,ya)
plt.xlabel('time')
plt.ylabel('acceleration')

plt.tight_layout()
plt.show()

# %%
umax = np.max(u)
ymax = np.max(np.abs([y,yv,ya]), axis = 1)
print(ymax)

u_norm = u/umax
y_norm = y/ymax[0]
yv_norm = yv/ymax[1]
ya_norm = ya/ymax[2]

N = len(u)
ntrain = int(N*0.5)
start = 50

print(ntrain)
utrain = u_norm[start:ntrain]
ytrain = y_norm[start:ntrain]
yvtrain = yv_norm[start:ntrain]
yatrain = ya_norm[start:ntrain]
ttrain = t[start:ntrain]
intrain = np.hstack([utrain,ytrain,yvtrain,yatrain])
outtrain = np.hstack([ytrain,yvtrain,yatrain])

utest = u_norm[ntrain:start+ntrain+2000]
ytest = y_norm[ntrain:start+ntrain+2000]
yvtest = yv_norm[ntrain:start+ntrain+2000]
yatest = ya_norm[ntrain:start+ntrain+2000]
ttest = t[ntrain:start+ntrain+2000]
intest = np.hstack([utest,ytest,yvtest,yatest])
outtest = np.hstack([ytest,yvtest,yatest])

ufull = np.concatenate([utrain, utest], axis = 0)
yfull = np.concatenate([ytrain, ytest], axis = 0)
infull = np.concatenate([intrain, intest], axis = 0)
outfull = np.concatenate([outtrain, outtest], axis = 0)

plt.figure(figsize=(12,12))
plt.subplot(4,1,1)
plt.plot(ttrain,utrain)
plt.plot(ttest,utest)
plt.xlabel('time')
plt.ylabel('force')

plt.subplot(4,1,2)
plt.plot(ttrain,ytrain)
plt.plot(ttest,ytest)
plt.xlabel('time')
plt.ylabel('displacement')

plt.subplot(4,1,3)
plt.plot(ttrain,yvtrain)
plt.plot(ttest,yvtest)
plt.xlabel('time')
plt.ylabel('velocity')

plt.subplot(4,1,4)
plt.plot(ttrain,yatrain)
plt.plot(ttest,yatest)
plt.xlabel('time')
plt.ylabel('acceleration')

plt.tight_layout()
plt.savefig('./../images/train_test_complete.tiff')
plt.show()
# Out:
# [[3.31365126e-02]
#  [5.66465450e+01]
#  [2.02096860e+05]]
# 5000

# %%
def create_inout_sequences(input_data, output_data, tw):
    xs = []
    ys = []

    for i in range(len(input_data)-tw-1):
        xya = input_data[i:(i+tw), 3]
        xyv = input_data[i:(i+tw), 2]
        xy = input_data[i:(i+tw), 1]
        xu = input_data[i+1:(i+tw)+1, 0]
        x = np.vstack([xu,xy,xyv,xya])
        y = output_data[i+tw,:]

        xs.append(x)
        ys.append(y)

    return np.transpose(np.array(xs),[0,1,2]), np.array(ys)

# %%
train_window = 12

x_train, y_train = create_inout_sequences(intrain, outtrain, train_window)
x_val, y_val = create_inout_sequences(intest, outtest, train_window)

x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

print(x_train.shape, y_train.shape)

x_full, y_full = create_inout_sequences(infull, outfull, train_window)

x_full = torch.from_numpy(x_full).float()
y_full = torch.from_numpy(y_full).float()

print(x_full.shape, y_full.shape)
# Out:
# torch.Size([4937, 4, 12]) torch.Size([4937, 3])
# torch.Size([6987, 4, 12]) torch.Size([6987, 3])

# %%
print(x_train.shape, y_train.shape, ytrain.shape)
plt.figure(figsize=(10,6))
plt.plot(ttrain[1:train_window+1], x_train[0,0,:])
plt.plot(ttrain[:train_window], x_train[0,1,:], linewidth = 3)
plt.scatter(ttrain[train_window], y_train[0,0], color = 'k')
plt.scatter(ttrain[train_window], y_train[0,1], color = 'k')
plt.scatter(ttrain[train_window], y_train[0,2], color = 'k')
plt.plot(ttrain[:train_window + 1], ytrain[:train_window + 1], 'k--')
plt.legend(['Input excitation', 'Past output passed as input', 
           'Actual output', 'Next time step'], loc = 'best')
plt.xlabel('Time, s')
plt.ylabel('Displacement, in')
plt.show()
# Out:
# torch.Size([4937, 4, 12]) torch.Size([4937, 3]) (4950, 1)

# %%
M = 2
alpha = [-1., 1., 0.]
beta = [0., 1.5, -0.5]

def RK_check(x, dx, dt, scalers, M = 2, alpha = [-1., 1., 0.], beta = [0., 1.5, -0.5]):
    x = x*scalers[:-1].T
    dx = dx*scalers[1:].T

    Y = alpha[0]*x[M:, :] + dt*beta[0]*dx[M:, :]
        
    for m in range(1, M+1):
        Y = Y + alpha[m]*x[M-m:-m, :] + dt*beta[m]*dx[M-m:-m,:]
        
    return Y/scalers[:-1].T*1e-1

dt = ttrain[1] - ttrain[0]

X = y_train[:, :-1]
DX = y_train[:, 1:]

print(ymax)

RK_check(X, DX, dt, ymax)
# Out:
# [[3.31365126e-02]
#  [5.66465450e+01]
#  [2.02096860e+05]]
# tensor([[-7.6356e-05,  2.2312e-03],
#         [ 4.5857e-05, -8.0137e-04],
#         [ 4.1698e-05,  7.5271e-04],
#         ...,
#         [ 4.1576e-05,  1.2034e-03],
#         [ 1.4845e-04,  4.6968e-05],
#         [ 3.4836e-04,  2.2918e-03]], dtype=torch.float64)

# %%
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils import weight_norm


class Chomp1d(nn.Module):
    def __init__(self, chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        return x[:, :, :-self.chomp_size].contiguous()


class TemporalBlock(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, padding, dropout=0.2):
        super(TemporalBlock, self).__init__()
        self.conv1 = weight_norm(nn.Conv1d(n_inputs, n_outputs, kernel_size,
                                           stride=stride, padding=padding, dilation=dilation))
        self.chomp1 = Chomp1d(padding)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.conv2 = weight_norm(nn.Conv1d(n_outputs, n_outputs, kernel_size,
                                           stride=stride, padding=padding, dilation=dilation))
        self.chomp2 = Chomp1d(padding)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.net = nn.Sequential(self.conv1, self.chomp1, self.relu1, self.dropout1,
                                 self.conv2, self.chomp2, self.relu2, self.dropout2)
        self.downsample = nn.Conv1d(n_inputs, n_outputs, 1) if n_inputs != n_outputs else None
        self.relu = nn.ReLU()
        self.init_weights()

    def init_weights(self):
        self.conv1.weight.data.normal_(0, 0.01)
        self.conv2.weight.data.normal_(0, 0.01)
        if self.downsample is not None:
            self.downsample.weight.data.normal_(0, 0.01)

    def forward(self, x):
        out = self.net(x)
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)


class TemporalConvNet(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size=2, dropout=0.2):
        super(TemporalConvNet, self).__init__()
        layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, dilation=dilation_size,
                                     padding=(kernel_size-1) * dilation_size, dropout=dropout)]

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# %%
import torch.nn.functional as F


class TCN(nn.Module):
    def __init__(self, input_size, output_size, num_channels, kernel_size, seq_len, dropout):
        super(TCN, self).__init__()
        self.seq_len = seq_len
        self.num_channels = num_channels
        self.tcn = TemporalConvNet(input_size, num_channels, kernel_size, dropout=dropout)
        self.linear = nn.Linear(num_channels[-1]*seq_len, output_size)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        # x needs to have dimension (N, C, L) in order to be passed into CNN
        output = self.tcn(x).transpose(1, 2).reshape((-1, self.seq_len*self.num_channels[-1]))
        output = self.linear(output).double()
        return output

# %%
model = TCN(input_size = 4, 
            output_size = 3, 
            num_channels = [6]*6, 
            kernel_size = 3, 
            seq_len = train_window, 
            dropout = 0.1)

# %%
lr = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_fn = torch.nn.MSELoss(reduction = "sum")

def train(model,epoch, X_train, Y_train, batch_size):
    global lr
    model.train()
    batch_idx = 1
    total_loss = 0
    for i in range(0, X_train.size(0), batch_size):
        if i + batch_size > X_train.size(0):
            x, y = X_train[i:, :, :], Y_train[i:]
        else:
            x, y = X_train[i:(i+batch_size), :, :], Y_train[i:(i+batch_size)]
        optimizer.zero_grad()
        output = model(x)
        
        # check derivatives
        X = output[:, :-1]
        DX = output[:, 1:]
        
        residual = RK_check(X, DX, dt, torch.from_numpy(ymax))

        loss = F.mse_loss(output, y.double()) + F.mse_loss(residual, torch.zeros(residual.shape).double())

        loss.backward()

        optimizer.step()
        batch_idx += 1
        total_loss += loss.item()

        if batch_idx % 25 == 0:
            cur_loss = total_loss / 25
            processed = min(i+batch_size, X_train.size(0))
            print('Train Epoch: {:2d} [{:6d}/{:6d} ({:.0f}%)]\tLearning rate: {:.4f}\tLoss: {:.6f}'.format(
                epoch, processed, X_train.size(0), 100.*processed/X_train.size(0), lr, cur_loss))
            total_loss = 0


def evaluate(model, X_test, Y_test):
    #model.eval()
    with torch.no_grad():
        output = model(X_test)
        test_loss = F.mse_loss(output, Y_test)
        print('\nTest set: Average loss: {:.6f}\n'.format(test_loss.item()))
        return test_loss.item()

# %%
epochs = 50000
batch_size = 250

for ep in range(1, epochs+1):
    train(model, ep, x_train, y_train, batch_size)
    print('Epoch: {}'.format(ep))
    tloss = evaluate(model, x_val, y_val)
# Out:
# Epoch: 1
#
# Test set: Average loss: 0.264175
#
# Epoch: 2
#
# Test set: Average loss: 0.214258
#
# Epoch: 3
#
# Test set: Average loss: 0.178115
#
# Epoch: 4
#
# Test set: Average loss: 0.151538
#
# Epoch: 5
#
# Test set: Average loss: 0.132060
#
# Epoch: 6
#
# Test set: Average loss: 0.117053
#
# Epoch: 7
#
# Test set: Average loss: 0.104609
#
# Epoch: 8
#
# Test set: Average loss: 0.096087
#
# Epoch: 9
#
# Test set: Average loss: 0.089535
#
# Epoch: 10
#
# Test set: Average loss: 0.084623
#
# Epoch: 11
#
# Test set: Average loss: 0.080005
#
# Epoch: 12
#
# Test set: Average loss: 0.077919
#
# Epoch: 13
#
# Test set: Average loss: 0.075038
#
# Epoch: 14
#
# Test set: Average loss: 0.073787
#
# Epoch: 15
#
# Test set: Average loss: 0.072958
#
# Epoch: 16
#
# Test set: Average loss: 0.072109
#
# Epoch: 17
#
# Test set: Average loss: 0.071969
#
# Epoch: 18
#
# Test set: Average loss: 0.070241
#
# Epoch: 19
#
# Test set: Average loss: 0.069561
#
# Epoch: 20
#
# Test set: Average loss: 0.068807
#
# Epoch: 21
#
# Test set: Average loss: 0.067341
#
# Epoch: 22
#
# Test set: Average loss: 0.065731
#
# Epoch: 23
#
# Test set: Average loss: 0.064188
#
# Epoch: 24
#
# Test set: Average loss: 0.062922
#
# Epoch: 25
#
# Test set: Average loss: 0.061482
#
# Epoch: 26
#
# Test set: Average loss: 0.059255
#
# Epoch: 27
#
# Test set: Average loss: 0.058228
#
# Epoch: 28
#
# Test set: Average loss: 0.055681
#
# Epoch: 29
#
# Test set: Average loss: 0.054113
#
# Epoch: 30
#
# Test set: Average loss: 0.052437
#
# Epoch: 31
#
# Test set: Average loss: 0.050323
#
# Epoch: 32
#
# Test set: Average loss: 0.048238
#
# Epoch: 33
#
# Test set: Average loss: 0.046600
#
# Epoch: 34
#
# Test set: Average loss: 0.043994
#
# Epoch: 35
#
# Test set: Average loss: 0.042374
#
# Epoch: 36
#
# Test set: Average loss: 0.040199
#
# Epoch: 37
#
# Test set: Average loss: 0.038531
#
# Epoch: 38
#
# Test set: Average loss: 0.036512
#
# Epoch: 39
#
# Test set: Average loss: 0.035056
#
# Epoch: 40
#
# Test set: Average loss: 0.033795
#
# Epoch: 41
#
# Test set: Average loss: 0.032555
#
# Epoch: 42
#
# Test set: Average loss: 0.031084
#
# Epoch: 43
#
# Test set: Average loss: 0.029942
#
# Epoch: 44
#
# Test set: Average loss: 0.029621
#
# Epoch: 45
#
# Test set: Average loss: 0.028255
#
# Epoch: 46
#
# Test set: Average loss: 0.028093
#
# Epoch: 47
#
# Test set: Average loss: 0.027496
#
# Epoch: 48
#
# Test set: Average loss: 0.026376
#
# Epoch: 49
#
# Test set: Average loss: 0.026305
#
# Epoch: 50
#
# Test set: Average loss: 0.025723
#
# Epoch: 51
#
# Test set: Average loss: 0.025399
#
# Epoch: 52
#
# Test set: Average loss: 0.025231
#
# Epoch: 53
#
# Test set: Average loss: 0.024465
#
# Epoch: 54
#
# Test set: Average loss: 0.024079
#
# Epoch: 55
#
# Test set: Average loss: 0.024171
#
# Epoch: 56
#
# Test set: Average loss: 0.024247
#
# Epoch: 57
#
# Test set: Average loss: 0.023647
#
# Epoch: 58
#
# Test set: Average loss: 0.022936
#
# Epoch: 59
#
# Test set: Average loss: 0.022882
#
# Epoch: 60
#
# Test set: Average loss: 0.022711
#
# Epoch: 61
#
# Test set: Average loss: 0.022599
#
# Epoch: 62
#
# Test set: Average loss: 0.022355
#
# Epoch: 63
#
# Test set: Average loss: 0.022020
#
# Epoch: 64
#
# Test set: Average loss: 0.021636
#
# Epoch: 65
#
# Test set: Average loss: 0.021669
#
# Epoch: 66
#
# Test set: Average loss: 0.020913
#
# Epoch: 67
#
# Test set: Average loss: 0.020923
#
# Epoch: 68
#
# Test set: Average loss: 0.020798
#
# Epoch: 69
#
# Test set: Average loss: 0.020499
#
# Epoch: 70
#
# Test set: Average loss: 0.020249
#
# Epoch: 71
#
# Test set: Average loss: 0.019824
#
# Epoch: 72
#
# Test set: Average loss: 0.019758
#
# Epoch: 73
#
# Test set: Average loss: 0.019677
#
# Epoch: 74
#
# Test set: Average loss: 0.019532
#
# Epoch: 75
#
# Test set: Average loss: 0.018903
#
# Epoch: 76
#
# Test set: Average loss: 0.019219
#
# Epoch: 77
#
# Test set: Average loss: 0.019081
#
# Epoch: 78
#
# Test set: Average loss: 0.018322
#
# Epoch: 79
#
# Test set: Average loss: 0.018503
#
# Epoch: 80
#
# Test set: Average loss: 0.018335
#
# Epoch: 81
#
# Test set: Average loss: 0.018111
#
# Epoch: 82
#
# Test set: Average loss: 0.017868
#
# Epoch: 83
#
# Test set: Average loss: 0.017334
#
# Epoch: 84
#
# Test set: Average loss: 0.017554
#
# Epoch: 85
#
# Test set: Average loss: 0.017342
#
# Epoch: 86
#
# Test set: Average loss: 0.017210
#
# Epoch: 87
#
# Test set: Average loss: 0.017292
#
# Epoch: 88
#
# Test set: Average loss: 0.017258
#
# Epoch: 89
#
# Test set: Average loss: 0.016708
#
# Epoch: 90
#
# Test set: Average loss: 0.016415
#
# Epoch: 91
#
# Test set: Average loss: 0.016329
#
# Epoch: 92
#
# Test set: Average loss: 0.015894
#
# Epoch: 93
#
# Test set: Average loss: 0.016157
#
# Epoch: 94
#
# Test set: Average loss: 0.015670
#
# Epoch: 95
#
# Test set: Average loss: 0.015546
#
# Epoch: 96
#
# Test set: Average loss: 0.015367
#
# Epoch: 97
#
# Test set: Average loss: 0.015002
#
# Epoch: 98
#
# Test set: Average loss: 0.014665
#
# Epoch: 99
#
# Test set: Average loss: 0.014895
#
# Epoch: 100
#
# Test set: Average loss: 0.014841
#
# Epoch: 101
#
# Test set: Average loss: 0.014620
#
# Epoch: 102
#
# Test set: Average loss: 0.014316
#
# Epoch: 103
#
# Test set: Average loss: 0.014237
#
# Epoch: 104
#
# Test set: Average loss: 0.013521
#
# Epoch: 105
#
# Test set: Average loss: 0.013867
#
# Epoch: 106
#
# Test set: Average loss: 0.013413
#
# Epoch: 107
#
# Test set: Average loss: 0.013342
#
# Epoch: 108
#
# Test set: Average loss: 0.013214
#
# Epoch: 109
#
# Test set: Average loss: 0.013316
#
# Epoch: 110
#
# Test set: Average loss: 0.013230
#
# Epoch: 111
#
# Test set: Average loss: 0.013191
#
# Epoch: 112
#
# Test set: Average loss: 0.012844
#
# Epoch: 113
#
# Test set: Average loss: 0.012886
#
# Epoch: 114
#
# Test set: Average loss: 0.012938
#
# Epoch: 115
#
# Test set: Average loss: 0.012689
#
# Epoch: 116
#
# Test set: Average loss: 0.012377
#
# Epoch: 117
#
# Test set: Average loss: 0.012405
#
# Epoch: 118
#
# Test set: Average loss: 0.012383
#
# Epoch: 119
#
# Test set: Average loss: 0.012193
#
# Epoch: 120
#
# Test set: Average loss: 0.011968
#
# Epoch: 121
#
# Test set: Average loss: 0.011975
#
# Epoch: 122
#
# Test set: Average loss: 0.011754
#
# Epoch: 123
#
# Test set: Average loss: 0.011814
#
# Epoch: 124
#
# Test set: Average loss: 0.011755
#
# Epoch: 125
#
# Test set: Average loss: 0.011513
#
# Epoch: 126
#
# Test set: Average loss: 0.011282
#
# Epoch: 127
#
# Test set: Average loss: 0.011167
#
# Epoch: 128
#
# Test set: Average loss: 0.011452
#
# Epoch: 129
#
# Test set: Average loss: 0.011407
#
# Epoch: 130
#
# Test set: Average loss: 0.010973
#
# Epoch: 131
#
# Test set: Average loss: 0.011144
#
# Epoch: 132
#
# Test set: Average loss: 0.010815
#
# Epoch: 133
#
# Test set: Average loss: 0.010786
#
# Epoch: 134
#
# Test set: Average loss: 0.010916
#
# Epoch: 135
#
# Test set: Average loss: 0.010795
#
# Epoch: 136
#
# Test set: Average loss: 0.010417
#
# Epoch: 137
#
# Test set: Average loss: 0.010602
#
# Epoch: 138
#
# Test set: Average loss: 0.010420
#
# Epoch: 139
#
# Test set: Average loss: 0.010466
#
# Epoch: 140
#
# Test set: Average loss: 0.009976
#
# Epoch: 141
#
# Test set: Average loss: 0.010354
#
# Epoch: 142
#
# Test set: Average loss: 0.010057
#
# Epoch: 143
#
# Test set: Average loss: 0.009904
#
# Epoch: 144
#
# Test set: Average loss: 0.010025
#
# Epoch: 145
#
# Test set: Average loss: 0.009976
#
# Epoch: 146
#
# Test set: Average loss: 0.010126
#
# Epoch: 147
#
# Test set: Average loss: 0.009822
#
# Epoch: 148
#
# Test set: Average loss: 0.009622
#
# Epoch: 149
#
# Test set: Average loss: 0.009477
#
# Epoch: 150
#
# Test set: Average loss: 0.009465
#
# Epoch: 151
#
# Test set: Average loss: 0.009243
#
# Epoch: 152
#
# Test set: Average loss: 0.009459
#
# Epoch: 153
#
# Test set: Average loss: 0.009189
#
# Epoch: 154
#
# Test set: Average loss: 0.009156
#
# Epoch: 155
#
# Test set: Average loss: 0.009249
#
# Epoch: 156
#
# Test set: Average loss: 0.008968
#
# Epoch: 157
#
# Test set: Average loss: 0.009039
#
# Epoch: 158
#
# Test set: Average loss: 0.008823
#
# Epoch: 159
#
# Test set: Average loss: 0.008823
#
# Epoch: 160
#
# Test set: Average loss: 0.008915
#
# Epoch: 161
#
# Test set: Average loss: 0.008880
#
# Epoch: 162
#
# Test set: Average loss: 0.008534
#
# Epoch: 163
#
# Test set: Average loss: 0.008461
#
# Epoch: 164
#
# Test set: Average loss: 0.008374
#
# Epoch: 165
#
# Test set: Average loss: 0.008675
#
# Epoch: 166
#
# Test set: Average loss: 0.008464
#
# Epoch: 167
#
# Test set: Average loss: 0.008460
#
# Epoch: 168
#
# Test set: Average loss: 0.008104
#
# Epoch: 169
#
# Test set: Average loss: 0.008174
#
# Epoch: 170
#
# Test set: Average loss: 0.008157
#
# Epoch: 171
#
# Test set: Average loss: 0.007941
#
# Epoch: 172
#
# Test set: Average loss: 0.007961
#
# Epoch: 173
#
# Test set: Average loss: 0.007840
#
# Epoch: 174
#
# Test set: Average loss: 0.007996
#
# Epoch: 175
#
# Test set: Average loss: 0.007892
#
# Epoch: 176
#
# Test set: Average loss: 0.007858
#
# Epoch: 177
#
# Test set: Average loss: 0.007550
#
# Epoch: 178
#
# Test set: Average loss: 0.007492
#
# Epoch: 179
#
# Test set: Average loss: 0.007657
#
# Epoch: 180
#
# Test set: Average loss: 0.007378
#
# Epoch: 181
#
# Test set: Average loss: 0.007365
# Epoch: 182
#
# Test set: Average loss: 0.007581
#
# Epoch: 183
#
# Test set: Average loss: 0.007134
#
# Epoch: 184
#
# Test set: Average loss: 0.007273
#
# Epoch: 185
#
# Test set: Average loss: 0.007267
#
# Epoch: 186
#
# Test set: Average loss: 0.007217
#
# Epoch: 187
#
# Test set: Average loss: 0.007162
#
# Epoch: 188
#
# Test set: Average loss: 0.007207
#
# Epoch: 189
#
# Test set: Average loss: 0.007151
#
# Epoch: 190
#
# Test set: Average loss: 0.006909
#
# Epoch: 191
#
# Test set: Average loss: 0.007070
#
# Epoch: 192
#
# Test set: Average loss: 0.006868
#
# Epoch: 193
#
# Test set: Average loss: 0.006894
#
# Epoch: 194
#
# Test set: Average loss: 0.006979
#
# Epoch: 195
#
# Test set: Average loss: 0.006851
#
# Epoch: 196
#
# Test set: Average loss: 0.006774
#
# Epoch: 197
#
# Test set: Average loss: 0.006752
#
# Epoch: 198
#
# Test set: Average loss: 0.006580
#
# Epoch: 199
#
# Test set: Average loss: 0.006477
#
# Epoch: 200
#
# Test set: Average loss: 0.006506
#
# Epoch: 201
#
# Test set: Average loss: 0.006493
#
# Epoch: 202
#
# Test set: Average loss: 0.006448
#
# Epoch: 203
#
# Test set: Average loss: 0.006471
#
# Epoch: 204
#
# Test set: Average loss: 0.006241
#
# Epoch: 205
#
# Test set: Average loss: 0.006238
#
# Epoch: 206
#
# Test set: Average loss: 0.006340
#
# Epoch: 207
#
# Test set: Average loss: 0.006282
#
# Epoch: 208
#
# Test set: Average loss: 0.006131
#
# Epoch: 209
#
# Test set: Average loss: 0.006071
#
# Epoch: 210
#
# Test set: Average loss: 0.005976
#
# Epoch: 211
#
# Test set: Average loss: 0.005858
#
# Epoch: 212
#
# Test set: Average loss: 0.005963
#
# Epoch: 213
#
# Test set: Average loss: 0.005802
#
# Epoch: 214
#
# Test set: Average loss: 0.005901
#
# Epoch: 215
#
# Test set: Average loss: 0.005964
#
# Epoch: 216
#
# Test set: Average loss: 0.005726
#
# Epoch: 217
#
# Test set: Average loss: 0.005678
#
# Epoch: 218
#
# Test set: Average loss: 0.005571
#
# Epoch: 219
#
# Test set: Average loss: 0.005620
#
# Epoch: 220
#
# Test set: Average loss: 0.005645
#
# Epoch: 221
#
# Test set: Average loss: 0.005596
#
# Epoch: 222
#
# Test set: Average loss: 0.005563
#
# Epoch: 223
#
# Test set: Average loss: 0.005515
#
# Epoch: 224
#
# Test set: Average loss: 0.005394
#
# Epoch: 225
#
# Test set: Average loss: 0.005306
#
# Epoch: 226
#
# Test set: Average loss: 0.005453
#
# Epoch: 227
#
# Test set: Average loss: 0.005284
#
# Epoch: 228
#
# Test set: Average loss: 0.005347
#
# Epoch: 229
#
# Test set: Average loss: 0.005098
#
# Epoch: 230
#
# Test set: Average loss: 0.005296
#
# Epoch: 231
#
# Test set: Average loss: 0.005154
#
# Epoch: 232
#
# Test set: Average loss: 0.005077
#
# Epoch: 233
#
# Test set: Average loss: 0.005144
#
# Epoch: 234
#
# Test set: Average loss: 0.005058
#
# Epoch: 235
#
# Test set: Average loss: 0.005001
#
# Epoch: 236
#
# Test set: Average loss: 0.004925
#
# Epoch: 237
#
# Test set: Average loss: 0.005022
#
# Epoch: 238
#
# Test set: Average loss: 0.004873
#
# Epoch: 239
#
# Test set: Average loss: 0.004898
#
# Epoch: 240
#
# Test set: Average loss: 0.004834
#
# Epoch: 241
#
# Test set: Average loss: 0.004912
#
# Epoch: 242
#
# Test set: Average loss: 0.004814
#
# Epoch: 243
#
# Test set: Average loss: 0.004885
#
# Epoch: 244
#
# Test set: Average loss: 0.004776
#
# Epoch: 245
#
# Test set: Average loss: 0.004715
#
# Epoch: 246
#
# Test set: Average loss: 0.004623
#
# Epoch: 247
#
# Test set: Average loss: 0.004618
#
# Epoch: 248
#
# Test set: Average loss: 0.004598
#
# Epoch: 249
#
# Test set: Average loss: 0.004422
#
# Epoch: 250
#
# Test set: Average loss: 0.004584
#
# Epoch: 251
#
# Test set: Average loss: 0.004410
#
# Epoch: 252
#
# Test set: Average loss: 0.004544
#
# Epoch: 253
#
# Test set: Average loss: 0.004462
#
# Epoch: 254
#
# Test set: Average loss: 0.004518
#
# Epoch: 255
#
# Test set: Average loss: 0.004400
#
# Epoch: 256
#
# Test set: Average loss: 0.004452
#
# Epoch: 257
#
# Test set: Average loss: 0.004208
#
# Epoch: 258
#
# Test set: Average loss: 0.004312
#
# Epoch: 259
#
# Test set: Average loss: 0.004319
#
# Epoch: 260
#
# Test set: Average loss: 0.004240
#
# Epoch: 261
#
# Test set: Average loss: 0.004118
#
# Epoch: 262
#
# Test set: Average loss: 0.004282
#
# Epoch: 263
#
# Test set: Average loss: 0.004178
#
# Epoch: 264
#
# Test set: Average loss: 0.004106
#
# Epoch: 265
#
# Test set: Average loss: 0.004024
#
# Epoch: 266
#
# Test set: Average loss: 0.004079
#
# Epoch: 267
#
# Test set: Average loss: 0.004004
#
# Epoch: 268
#
# Test set: Average loss: 0.004024
#
# Epoch: 269
#
# Test set: Average loss: 0.003932
#
# Epoch: 270
#
# Test set: Average loss: 0.003994
#
# Epoch: 271
#
# Test set: Average loss: 0.003962
#
# Epoch: 272
#
# Test set: Average loss: 0.003928
#
# Epoch: 273
#
# Test set: Average loss: 0.003888
#
# Epoch: 274
#
# Test set: Average loss: 0.003912
#
# Epoch: 275
#
# Test set: Average loss: 0.003852
#
# Epoch: 276
#
# Test set: Average loss: 0.003812
#
# Epoch: 277
#
# Test set: Average loss: 0.003866
#
# Epoch: 278
#
# Test set: Average loss: 0.003702
#
# Epoch: 279
#
# Test set: Average loss: 0.003847
#
# Epoch: 280
#
# Test set: Average loss: 0.003813
#
# Epoch: 281
#
# Test set: Average loss: 0.003609
#
# Epoch: 282
#
# Test set: Average loss: 0.003766
#
# Epoch: 283
#
# Test set: Average loss: 0.003729
#
# Epoch: 284
#
# Test set: Average loss: 0.003581
#
# Epoch: 285
#
# Test set: Average loss: 0.003711
#
# Epoch: 286
#
# Test set: Average loss: 0.003722
#
# Epoch: 287
#
# Test set: Average loss: 0.003586
#
# Epoch: 288
#
# Test set: Average loss: 0.003671
#
# Epoch: 289
#
# Test set: Average loss: 0.003650
#
# Epoch: 290
#
# Test set: Average loss: 0.003509
#
# Epoch: 291
#
# Test set: Average loss: 0.003468
#
# Epoch: 292
#
# Test set: Average loss: 0.003484
#
# Epoch: 293
#
# Test set: Average loss: 0.003518
#
# Epoch: 294
#
# Test set: Average loss: 0.003446
#
# Epoch: 295
#
# Test set: Average loss: 0.003470
#
# Epoch: 296
#
# Test set: Average loss: 0.003441
#
# Epoch: 297
#
# Test set: Average loss: 0.003393
#
# Epoch: 298
#
# Test set: Average loss: 0.003358
#
# Epoch: 299
#
# Test set: Average loss: 0.003364
#
# Epoch: 300
#
# Test set: Average loss: 0.003372
#
# Epoch: 301
#
# Test set: Average loss: 0.003354
#
# Epoch: 302
#
# Test set: Average loss: 0.003373
#
# Epoch: 303
#
# Test set: Average loss: 0.003315
#
# Epoch: 304
#
# Test set: Average loss: 0.003176
#
# Epoch: 305
#
# Test set: Average loss: 0.003223
#
# Epoch: 306
#
# Test set: Average loss: 0.003212
#
# Epoch: 307
#
# Test set: Average loss: 0.003177
#
# Epoch: 308
#
# Test set: Average loss: 0.003225
#
# Epoch: 309
#
# Test set: Average loss: 0.003064
#
# Epoch: 310
#
# Test set: Average loss: 0.003240
#
# Epoch: 311
#
# Test set: Average loss: 0.003114
#
# Epoch: 312
#
# Test set: Average loss: 0.003096
#
# Epoch: 313
#
# Test set: Average loss: 0.003066
#
# Epoch: 314
#
# Test set: Average loss: 0.003026
#
# Epoch: 315
#
# Test set: Average loss: 0.003115
#
# Epoch: 316
#
# Test set: Average loss: 0.003058
#
# Epoch: 317
#
# Test set: Average loss: 0.003034
#
# Epoch: 318
#
# Test set: Average loss: 0.002996
#
# Epoch: 319
#
# Test set: Average loss: 0.002980
#
# Epoch: 320
#
# Test set: Average loss: 0.003003
#
# Epoch: 321
#
# Test set: Average loss: 0.002956
#
# Epoch: 322
#
# Test set: Average loss: 0.002908
#
# Epoch: 323
#
# Test set: Average loss: 0.002922
#
# Epoch: 324
#
# Test set: Average loss: 0.002858
#
# Epoch: 325
#
# Test set: Average loss: 0.002853
#
# Epoch: 326
#
# Test set: Average loss: 0.002861
#
# Epoch: 327
#
# Test set: Average loss: 0.002894
#
# Epoch: 328
#
# Test set: Average loss: 0.002824
#
# Epoch: 329
#
# Test set: Average loss: 0.002828
#
# Epoch: 330
#
# Test set: Average loss: 0.002734
#
# Epoch: 331
#
# Test set: Average loss: 0.002686
#
# Epoch: 332
#
# Test set: Average loss: 0.002746
#
# Epoch: 333
#
# Test set: Average loss: 0.002773
#
# Epoch: 334
#
# Test set: Average loss: 0.002692
#
# Epoch: 335
#
# Test set: Average loss: 0.002667
#
# Epoch: 336
#
# Test set: Average loss: 0.002653
#
# Epoch: 337
#
# Test set: Average loss: 0.002759
#
# Epoch: 338
#
# Test set: Average loss: 0.002666
#
# Epoch: 339
#
# Test set: Average loss: 0.002664
#
# Epoch: 340
#
# Test set: Average loss: 0.002631
#
# Epoch: 341
#
# Test set: Average loss: 0.002562
#
# Epoch: 342
#
# Test set: Average loss: 0.002593
#
# Epoch: 343
#
# Test set: Average loss: 0.002601
#
# Epoch: 344
#
# Test set: Average loss: 0.002590
#
# Epoch: 345
#
# Test set: Average loss: 0.002539
#
# Epoch: 346
#
# Test set: Average loss: 0.002485
#
# Epoch: 347
#
# Test set: Average loss: 0.002647
#
# Epoch: 348
#
# Test set: Average loss: 0.002548
#
# Epoch: 349
#
# Test set: Average loss: 0.002571
#
# Epoch: 350
#
# Test set: Average loss: 0.002575
#
# Epoch: 351
#
# Test set: Average loss: 0.002385
#
# Epoch: 352
#
# Test set: Average loss: 0.002508
#
# Epoch: 353
#
# Test set: Average loss: 0.002396
#
# Epoch: 354
#
# Test set: Average loss: 0.002427
#
# Epoch: 355
#
# Test set: Average loss: 0.002396
#
# Epoch: 356
#
# Test set: Average loss: 0.002364
#
# Epoch: 357
#
# Test set: Average loss: 0.002389
#
# Epoch: 358
#
# Test set: Average loss: 0.002349
#
# Epoch: 359
#
# Test set: Average loss: 0.002465
#
# Epoch: 360
# Test set: Average loss: 0.002427
#
# Epoch: 361
#
# Test set: Average loss: 0.002372
#
# Epoch: 362
#
# Test set: Average loss: 0.002283
#
# Epoch: 363
#
# Test set: Average loss: 0.002384
#
# Epoch: 364
#
# Test set: Average loss: 0.002339
#
# Epoch: 365
#
# Test set: Average loss: 0.002296
#
# Epoch: 366
#
# Test set: Average loss: 0.002329
#
# Epoch: 367
#
# Test set: Average loss: 0.002326
#
# Epoch: 368
#
# Test set: Average loss: 0.002341
#
# Epoch: 369
#
# Test set: Average loss: 0.002242
#
# Epoch: 370
#
# Test set: Average loss: 0.002313
#
# Epoch: 371
#
# Test set: Average loss: 0.002219
#
# Epoch: 372
#
# Test set: Average loss: 0.002273
#
# Epoch: 373
#
# Test set: Average loss: 0.002245
#
# Epoch: 374
#
# Test set: Average loss: 0.002213
#
# Epoch: 375
#
# Test set: Average loss: 0.002265
#
# Epoch: 376
#
# Test set: Average loss: 0.002270
#
# Epoch: 377
#
# Test set: Average loss: 0.002100
#
# Epoch: 378
#
# Test set: Average loss: 0.002167
#
# Epoch: 379
#
# Test set: Average loss: 0.002126
#
# Epoch: 380
#
# Test set: Average loss: 0.002142
#
# Epoch: 381
#
# Test set: Average loss: 0.002103
#
# Epoch: 382
#
# Test set: Average loss: 0.002148
#
# Epoch: 383
#
# Test set: Average loss: 0.002125
#
# Epoch: 384
#
# Test set: Average loss: 0.002111
#
# Epoch: 385
#
# Test set: Average loss: 0.002087
#
# Epoch: 386
#
# Test set: Average loss: 0.002085
#
# Epoch: 387
#
# Test set: Average loss: 0.001986
#
# Epoch: 388
#
# Test set: Average loss: 0.002051
#
# Epoch: 389
#
# Test set: Average loss: 0.002084
#
# Epoch: 390
#
# Test set: Average loss: 0.002012
#
# Epoch: 391
#
# Test set: Average loss: 0.002048
#
# Epoch: 392
#
# Test set: Average loss: 0.002028
#
# Epoch: 393
#
# Test set: Average loss: 0.002003
#
# Epoch: 394
#
# Test set: Average loss: 0.002046
#
# Epoch: 395
#
# Test set: Average loss: 0.001972
#
# Epoch: 396
#
# Test set: Average loss: 0.001946
#
# Epoch: 397
#
# Test set: Average loss: 0.002015
#
# Epoch: 398
#
# Test set: Average loss: 0.002009
#
# Epoch: 399
#
# Test set: Average loss: 0.001924
#
# Epoch: 400
#
# Test set: Average loss: 0.001946
#
# Epoch: 401
#
# Test set: Average loss: 0.001858
#
# Epoch: 402
#
# Test set: Average loss: 0.001908
#
# Epoch: 403
#
# Test set: Average loss: 0.001928
#
# Epoch: 404
#
# Test set: Average loss: 0.001965
#
# Epoch: 405
#
# Test set: Average loss: 0.001923
#
# Epoch: 406
#
# Test set: Average loss: 0.001897
#
# Epoch: 407
#
# Test set: Average loss: 0.001855
#
# Epoch: 408
#
# Test set: Average loss: 0.001888
#
# Epoch: 409
#
# Test set: Average loss: 0.001819
#
# Epoch: 410
#
# Test set: Average loss: 0.001845
#
# Epoch: 411
#
# Test set: Average loss: 0.001845
#
# Epoch: 412
#
# Test set: Average loss: 0.001847
#
# Epoch: 413
#
# Test set: Average loss: 0.001786
#
# Epoch: 414
#
# Test set: Average loss: 0.001871
#
# Epoch: 415
#
# Test set: Average loss: 0.001842
#
# Epoch: 416
#
# Test set: Average loss: 0.001832
#
# Epoch: 417
#
# Test set: Average loss: 0.001763
#
# Epoch: 418
#
# Test set: Average loss: 0.001772
#
# Epoch: 419
#
# Test set: Average loss: 0.001815
#
# Epoch: 420
#
# Test set: Average loss: 0.001730
#
# Epoch: 421
#
# Test set: Average loss: 0.001704
#
# Epoch: 422
#
# Test set: Average loss: 0.001739
#
# Epoch: 423
#
# Test set: Average loss: 0.001775
#
# Epoch: 424
#
# Test set: Average loss: 0.001814
#
# Epoch: 425
#
# Test set: Average loss: 0.001750
#
# Epoch: 426
#
# Test set: Average loss: 0.001727
#
# Epoch: 427
#
# Test set: Average loss: 0.001722
#
# Epoch: 428
#
# Test set: Average loss: 0.001741
#
# Epoch: 429
#
# Test set: Average loss: 0.001706
#
# Epoch: 430
#
# Test set: Average loss: 0.001703
#
# Epoch: 431
#
# Test set: Average loss: 0.001737
#
# Epoch: 432
#
# Test set: Average loss: 0.001659
#
# Epoch: 433
#
# Test set: Average loss: 0.001704
#
# Epoch: 434
#
# Test set: Average loss: 0.001709
#
# Epoch: 435
#
# Test set: Average loss: 0.001665
#
# Epoch: 436
#
# Test set: Average loss: 0.001703
#
# Epoch: 437
#
# Test set: Average loss: 0.001720
#
# Epoch: 438
#
# Test set: Average loss: 0.001651
#
# Epoch: 439
#
# Test set: Average loss: 0.001674
#
# Epoch: 440
#
# Test set: Average loss: 0.001587
#
# Epoch: 441
#
# Test set: Average loss: 0.001609
#
# Epoch: 442
#
# Test set: Average loss: 0.001651
#
# Epoch: 443
#
# Test set: Average loss: 0.001561
#
# Epoch: 444
#
# Test set: Average loss: 0.001590
#
# Epoch: 445
#
# Test set: Average loss: 0.001591
#
# Epoch: 446
#
# Test set: Average loss: 0.001614
#
# Epoch: 447
#
# Test set: Average loss: 0.001640
#
# Epoch: 448
#
# Test set: Average loss: 0.001609
#
# Epoch: 449
#
# Test set: Average loss: 0.001585
#
# Epoch: 450
#
# Test set: Average loss: 0.001581
#
# Epoch: 451
#
# Test set: Average loss: 0.001578
#
# Epoch: 452
#
# Test set: Average loss: 0.001577
#
# Epoch: 453
#
# Test set: Average loss: 0.001616
#
# Epoch: 454
#
# Test set: Average loss: 0.001525
#
# Epoch: 455
#
# Test set: Average loss: 0.001588
#
# Epoch: 456
#
# Test set: Average loss: 0.001498
#
# Epoch: 457
#
# Test set: Average loss: 0.001534
#
# Epoch: 458
#
# Test set: Average loss: 0.001556
#
# Epoch: 459
#
# Test set: Average loss: 0.001585
#
# Epoch: 460
#
# Test set: Average loss: 0.001513
#
# Epoch: 461
#
# Test set: Average loss: 0.001495
#
# Epoch: 462
#
# Test set: Average loss: 0.001501
#
# Epoch: 463
#
# Test set: Average loss: 0.001483
#
# Epoch: 464
#
# Test set: Average loss: 0.001496
#
# Epoch: 465
#
# Test set: Average loss: 0.001436
#
# Epoch: 466
#
# Test set: Average loss: 0.001457
#
# Epoch: 467
#
# Test set: Average loss: 0.001468
#
# Epoch: 468
#
# Test set: Average loss: 0.001483
#
# Epoch: 469
#
# Test set: Average loss: 0.001411
#
# Epoch: 470
#
# Test set: Average loss: 0.001478
#
# Epoch: 471
#
# Test set: Average loss: 0.001447
#
# Epoch: 472
#
# Test set: Average loss: 0.001392
#
# Epoch: 473
#
# Test set: Average loss: 0.001468
#
# Epoch: 474
#
# Test set: Average loss: 0.001456
#
# Epoch: 475
#
# Test set: Average loss: 0.001465
#
# Epoch: 476
#
# Test set: Average loss: 0.001416
#
# Epoch: 477
#
# Test set: Average loss: 0.001409
#
# Epoch: 478
#
# Test set: Average loss: 0.001380
#
# Epoch: 479
#
# Test set: Average loss: 0.001416
#
# Epoch: 480
#
# Test set: Average loss: 0.001408
#
# Epoch: 481
#
# Test set: Average loss: 0.001372
#
# Epoch: 482
#
# Test set: Average loss: 0.001384
#
# Epoch: 483
#
# Test set: Average loss: 0.001411
#
# Epoch: 484
#
# Test set: Average loss: 0.001341
#
# Epoch: 485
#
# Test set: Average loss: 0.001330
#
# Epoch: 486
#
# Test set: Average loss: 0.001383
#
# Epoch: 487
#
# Test set: Average loss: 0.001372
#
# Epoch: 488
#
# Test set: Average loss: 0.001324
#
# Epoch: 489
#
# Test set: Average loss: 0.001305
#
# Epoch: 490
#
# Test set: Average loss: 0.001374
#
# Epoch: 491
#
# Test set: Average loss: 0.001336
#
# Epoch: 492
#
# Test set: Average loss: 0.001293
#
# Epoch: 493
#
# Test set: Average loss: 0.001313
#
# Epoch: 494
#
# Test set: Average loss: 0.001300
#
# Epoch: 495
#
# Test set: Average loss: 0.001325
#
# Epoch: 496
#
# Test set: Average loss: 0.001256
#
# Epoch: 497
#
# Test set: Average loss: 0.001329
#
# Epoch: 498
#
# Test set: Average loss: 0.001283
#
# Epoch: 499
#
# Test set: Average loss: 0.001382
#
# Epoch: 500
#
# Test set: Average loss: 0.001288
#
# Epoch: 501
#
# Test set: Average loss: 0.001300
#
# Epoch: 502
#
# Test set: Average loss: 0.001340
#
# Epoch: 503
#
# Test set: Average loss: 0.001267
#
# Epoch: 504
#
# Test set: Average loss: 0.001291
#
# Epoch: 505
#
# Test set: Average loss: 0.001232
#
# Epoch: 506
#
# Test set: Average loss: 0.001320
#
# Epoch: 507
#
# Test set: Average loss: 0.001271
#
# Epoch: 508
#
# Test set: Average loss: 0.001289
#
# Epoch: 509
#
# Test set: Average loss: 0.001280
#
# Epoch: 510
#
# Test set: Average loss: 0.001215
#
# Epoch: 511
#
# Test set: Average loss: 0.001248
#
# Epoch: 512
#
# Test set: Average loss: 0.001233
#
# Epoch: 513
#
# Test set: Average loss: 0.001295
#
# Epoch: 514
#
# Test set: Average loss: 0.001247
#
# Epoch: 515
#
# Test set: Average loss: 0.001235
#
# Epoch: 516
#
# Test set: Average loss: 0.001238
#
# Epoch: 517
#
# Test set: Average loss: 0.001186
#
# Epoch: 518
#
# Test set: Average loss: 0.001212
#
# Epoch: 519
#
# Test set: Average loss: 0.001207
#
# Epoch: 520
#
# Test set: Average loss: 0.001216
#
# Epoch: 521
#
# Test set: Average loss: 0.001224
#
# Epoch: 522
#
# Test set: Average loss: 0.001185
#
# Epoch: 523
#
# Test set: Average loss: 0.001234
#
# Epoch: 524
#
# Test set: Average loss: 0.001196
#
# Epoch: 525
#
# Test set: Average loss: 0.001179
#
# Epoch: 526
#
# Test set: Average loss: 0.001222
#
# Epoch: 527
#
# Test set: Average loss: 0.001159
#
# Epoch: 528
#
# Test set: Average loss: 0.001196
#
# Epoch: 529
#
# Test set: Average loss: 0.001149
#
# Epoch: 530
#
# Test set: Average loss: 0.001121
#
# Epoch: 531
#
# Test set: Average loss: 0.001178
#
# Epoch: 532
#
# Test set: Average loss: 0.001176
#
# Epoch: 533
#
# Test set: Average loss: 0.001153
#
# Epoch: 534
#
# Test set: Average loss: 0.001153
#
# Epoch: 535
#
# Test set: Average loss: 0.001143
#
# Epoch: 536
#
# Test set: Average loss: 0.001139
#
# Epoch: 537
#
# Test set: Average loss: 0.001168
#
# Epoch: 538
#
# Test set: Average loss: 0.001143
# Epoch: 539
#
# Test set: Average loss: 0.001201
#
# Epoch: 540
#
# Test set: Average loss: 0.001131
#
# Epoch: 541
#
# Test set: Average loss: 0.001131
#
# Epoch: 542
#
# Test set: Average loss: 0.001157
#
# Epoch: 543
#
# Test set: Average loss: 0.001144
#
# Epoch: 544
#
# Test set: Average loss: 0.001130
#
# Epoch: 545
#
# Test set: Average loss: 0.001079
#
# Epoch: 546
#
# Test set: Average loss: 0.001137
#
# Epoch: 547
#
# Test set: Average loss: 0.001116
#
# Epoch: 548
#
# Test set: Average loss: 0.001127
#
# Epoch: 549
#
# Test set: Average loss: 0.001118
#
# Epoch: 550
#
# Test set: Average loss: 0.001114
#
# Epoch: 551
#
# Test set: Average loss: 0.001118
#
# Epoch: 552
#
# Test set: Average loss: 0.001144
#
# Epoch: 553
#
# Test set: Average loss: 0.001122
#
# Epoch: 554
#
# Test set: Average loss: 0.001110
#
# Epoch: 555
#
# Test set: Average loss: 0.001065
#
# Epoch: 556
#
# Test set: Average loss: 0.001076
#
# Epoch: 557
#
# Test set: Average loss: 0.001088
#
# Epoch: 558
#
# Test set: Average loss: 0.001110
#
# Epoch: 559
#
# Test set: Average loss: 0.001049
#
# Epoch: 560
#
# Test set: Average loss: 0.001078
#
# Epoch: 561
#
# Test set: Average loss: 0.001115
#
# Epoch: 562
#
# Test set: Average loss: 0.001062
#
# Epoch: 563
#
# Test set: Average loss: 0.001036
#
# Epoch: 564
#
# Test set: Average loss: 0.001084
#
# Epoch: 565
#
# Test set: Average loss: 0.001022
#
# Epoch: 566
#
# Test set: Average loss: 0.001064
#
# Epoch: 567
#
# Test set: Average loss: 0.001052
#
# Epoch: 568
#
# Test set: Average loss: 0.001039
#
# Epoch: 569
#
# Test set: Average loss: 0.001077
#
# Epoch: 570
#
# Test set: Average loss: 0.001048
#
# Epoch: 571
#
# Test set: Average loss: 0.001057
#
# Epoch: 572
#
# Test set: Average loss: 0.001036
#
# Epoch: 573
#
# Test set: Average loss: 0.001054
#
# Epoch: 574
#
# Test set: Average loss: 0.001031
#
# Epoch: 575
#
# Test set: Average loss: 0.001050
#
# Epoch: 576
#
# Test set: Average loss: 0.001049
#
# Epoch: 577
#
# Test set: Average loss: 0.001006
#
# Epoch: 578
#
# Test set: Average loss: 0.001035
#
# Epoch: 579
#
# Test set: Average loss: 0.001074
#
# Epoch: 580
#
# Test set: Average loss: 0.000984
#
# Epoch: 581
#
# Test set: Average loss: 0.000964
#
# Epoch: 582
#
# Test set: Average loss: 0.001037
#
# Epoch: 583
#
# Test set: Average loss: 0.000983
#
# Epoch: 584
#
# Test set: Average loss: 0.000958
#
# Epoch: 585
#
# Test set: Average loss: 0.000943
#
# Epoch: 586
#
# Test set: Average loss: 0.001026
#
# Epoch: 587
#
# Test set: Average loss: 0.001014
#
# Epoch: 588
#
# Test set: Average loss: 0.000987
#
# Epoch: 589
#
# Test set: Average loss: 0.000960
#
# Epoch: 590
#
# Test set: Average loss: 0.000968
#
# Epoch: 591
#
# Test set: Average loss: 0.001000
#
# Epoch: 592
#
# Test set: Average loss: 0.000985
#
# Epoch: 593
#
# Test set: Average loss: 0.000988
#
# Epoch: 594
#
# Test set: Average loss: 0.000978
#
# Epoch: 595
#
# Test set: Average loss: 0.000965
#
# Epoch: 596
#
# Test set: Average loss: 0.000945
#
# Epoch: 597
#
# Test set: Average loss: 0.000988
#
# Epoch: 598
#
# Test set: Average loss: 0.000973
#
# Epoch: 599
#
# Test set: Average loss: 0.000989
#
# Epoch: 600
#
# Test set: Average loss: 0.000978
#
# Epoch: 601
#
# Test set: Average loss: 0.000964
#
# Epoch: 602
#
# Test set: Average loss: 0.000942
#
# Epoch: 603
#
# Test set: Average loss: 0.000964
#
# Epoch: 604
#
# Test set: Average loss: 0.000929
#
# Epoch: 605
#
# Test set: Average loss: 0.000984
#
# Epoch: 606
#
# Test set: Average loss: 0.000947
#
# Epoch: 607
#
# Test set: Average loss: 0.000963
#
# Epoch: 608
#
# Test set: Average loss: 0.000946
#
# Epoch: 609
#
# Test set: Average loss: 0.000887
#
# Epoch: 610
#
# Test set: Average loss: 0.000947
#
# Epoch: 611
#
# Test set: Average loss: 0.000955
#
# Epoch: 612
#
# Test set: Average loss: 0.000952
#
# Epoch: 613
#
# Test set: Average loss: 0.000949
#
# Epoch: 614
#
# Test set: Average loss: 0.000924
#
# Epoch: 615
#
# Test set: Average loss: 0.000952
#
# Epoch: 616
#
# Test set: Average loss: 0.000900
#
# Epoch: 617
#
# Test set: Average loss: 0.000902
#
# Epoch: 618
#
# Test set: Average loss: 0.000911
#
# Epoch: 619
#
# Test set: Average loss: 0.000927
#
# Epoch: 620
#
# Test set: Average loss: 0.000912
#
# Epoch: 621
#
# Test set: Average loss: 0.000902
#
# Epoch: 622
#
# Test set: Average loss: 0.000930
#
# Epoch: 623
#
# Test set: Average loss: 0.000908
#
# Epoch: 624
#
# Test set: Average loss: 0.000908
#
# Epoch: 625
#
# Test set: Average loss: 0.000898
#
# Epoch: 626
#
# Test set: Average loss: 0.000884
#
# Epoch: 627
#
# Test set: Average loss: 0.000879
#
# Epoch: 628
#
# Test set: Average loss: 0.000924
#
# Epoch: 629
#
# Test set: Average loss: 0.000903
#
# Epoch: 630
#
# Test set: Average loss: 0.000864
#
# Epoch: 631
#
# Test set: Average loss: 0.000867
#
# Epoch: 632
#
# Test set: Average loss: 0.000888
#
# Epoch: 633
#
# Test set: Average loss: 0.000913
#
# Epoch: 634
#
# Test set: Average loss: 0.000869
#
# Epoch: 635
#
# Test set: Average loss: 0.000869
#
# Epoch: 636
#
# Test set: Average loss: 0.000900
#
# Epoch: 637
#
# Test set: Average loss: 0.000876
#
# Epoch: 638
#
# Test set: Average loss: 0.000882
#
# Epoch: 639
#
# Test set: Average loss: 0.000874
#
# Epoch: 640
#
# Test set: Average loss: 0.000899
#
# Epoch: 641
#
# Test set: Average loss: 0.000889
#
# Epoch: 642
#
# Test set: Average loss: 0.000868
#
# Epoch: 643
#
# Test set: Average loss: 0.000852
#
# Epoch: 644
#
# Test set: Average loss: 0.000871
#
# Epoch: 645
#
# Test set: Average loss: 0.000865
#
# Epoch: 646
#
# Test set: Average loss: 0.000848
#
# Epoch: 647
#
# Test set: Average loss: 0.000831
#
# Epoch: 648
#
# Test set: Average loss: 0.000858
#
# Epoch: 649
#
# Test set: Average loss: 0.000831
#
# Epoch: 650
#
# Test set: Average loss: 0.000855
#
# Epoch: 651
#
# Test set: Average loss: 0.000884
#
# Epoch: 652
#
# Test set: Average loss: 0.000872
#
# Epoch: 653
#
# Test set: Average loss: 0.000868
#
# Epoch: 654
#
# Test set: Average loss: 0.000815
#
# Epoch: 655
#
# Test set: Average loss: 0.000829
#
# Epoch: 656
#
# Test set: Average loss: 0.000840
#
# Epoch: 657
#
# Test set: Average loss: 0.000859
#
# Epoch: 658
#
# Test set: Average loss: 0.000845
#
# Epoch: 659
#
# Test set: Average loss: 0.000844
#
# Epoch: 660
#
# Test set: Average loss: 0.000836
#
# Epoch: 661
#
# Test set: Average loss: 0.000824
#
# Epoch: 662
#
# Test set: Average loss: 0.000850
#
# Epoch: 663
#
# Test set: Average loss: 0.000831
#
# Epoch: 664
#
# Test set: Average loss: 0.000834
#
# Epoch: 665
#
# Test set: Average loss: 0.000825
#
# Epoch: 666
#
# Test set: Average loss: 0.000812
#
# Epoch: 667
#
# Test set: Average loss: 0.000815
#
# Epoch: 668
#
# Test set: Average loss: 0.000813
#
# Epoch: 669
#
# Test set: Average loss: 0.000857
#
# Epoch: 670
#
# Test set: Average loss: 0.000825
#
# Epoch: 671
#
# Test set: Average loss: 0.000849
#
# Epoch: 672
#
# Test set: Average loss: 0.000844
#
# Epoch: 673
#
# Test set: Average loss: 0.000843
#
# Epoch: 674
#
# Test set: Average loss: 0.000816
#
# Epoch: 675
#
# Test set: Average loss: 0.000814
#
# Epoch: 676
#
# Test set: Average loss: 0.000793
#
# Epoch: 677
#
# Test set: Average loss: 0.000793
#
# Epoch: 678
#
# Test set: Average loss: 0.000795
#
# Epoch: 679
#
# Test set: Average loss: 0.000793
#
# Epoch: 680
#
# Test set: Average loss: 0.000781
#
# Epoch: 681
#
# Test set: Average loss: 0.000798
#
# Epoch: 682
#
# Test set: Average loss: 0.000810
#
# Epoch: 683
#
# Test set: Average loss: 0.000766
#
# Epoch: 684
#
# Test set: Average loss: 0.000790
#
# Epoch: 685
#
# Test set: Average loss: 0.000797
#
# Epoch: 686
#
# Test set: Average loss: 0.000778
#
# Epoch: 687
#
# Test set: Average loss: 0.000784
#
# Epoch: 688
#
# Test set: Average loss: 0.000785
#
# Epoch: 689
#
# Test set: Average loss: 0.000798
#
# Epoch: 690
#
# Test set: Average loss: 0.000769
#
# Epoch: 691
#
# Test set: Average loss: 0.000759
#
# Epoch: 692
#
# Test set: Average loss: 0.000771
#
# Epoch: 693
#
# Test set: Average loss: 0.000778
#
# Epoch: 694
#
# Test set: Average loss: 0.000757
#
# Epoch: 695
#
# Test set: Average loss: 0.000794
#
# Epoch: 696
#
# Test set: Average loss: 0.000785
#
# Epoch: 697
#
# Test set: Average loss: 0.000783
#
# Epoch: 698
#
# Test set: Average loss: 0.000787
#
# Epoch: 699
#
# Test set: Average loss: 0.000767
#
# Epoch: 700
#
# Test set: Average loss: 0.000777
#
# Epoch: 701
#
# Test set: Average loss: 0.000768
#
# Epoch: 702
#
# Test set: Average loss: 0.000780
#
# Epoch: 703
#
# Test set: Average loss: 0.000764
#
# Epoch: 704
#
# Test set: Average loss: 0.000772
#
# Epoch: 705
#
# Test set: Average loss: 0.000762
#
# Epoch: 706
#
# Test set: Average loss: 0.000770
#
# Epoch: 707
#
# Test set: Average loss: 0.000783
#
# Epoch: 708
#
# Test set: Average loss: 0.000743
#
# Epoch: 709
#
# Test set: Average loss: 0.000783
#
# Epoch: 710
#
# Test set: Average loss: 0.000734
#
# Epoch: 711
#
# Test set: Average loss: 0.000758
#
# Epoch: 712
#
# Test set: Average loss: 0.000746
#
# Epoch: 713
#
# Test set: Average loss: 0.000781
#
# Epoch: 714
#
# Test set: Average loss: 0.000725
#
# Epoch: 715
#
# Test set: Average loss: 0.000759
#
# Epoch: 716
#
# Test set: Average loss: 0.000757
#
# Epoch: 717
# Test set: Average loss: 0.000744
#
# Epoch: 718
#
# Test set: Average loss: 0.000732
#
# Epoch: 719
#
# Test set: Average loss: 0.000716
#
# Epoch: 720
#
# Test set: Average loss: 0.000719
#
# Epoch: 721
#
# Test set: Average loss: 0.000722
#
# Epoch: 722
#
# Test set: Average loss: 0.000745
#
# Epoch: 723
#
# Test set: Average loss: 0.000734
#
# Epoch: 724
#
# Test set: Average loss: 0.000735
#
# Epoch: 725
#
# Test set: Average loss: 0.000742
#
# Epoch: 726
#
# Test set: Average loss: 0.000741
#
# Epoch: 727
#
# Test set: Average loss: 0.000738
#
# Epoch: 728
#
# Test set: Average loss: 0.000708
#
# Epoch: 729
#
# Test set: Average loss: 0.000746
#
# Epoch: 730
#
# Test set: Average loss: 0.000697
#
# Epoch: 731
#
# Test set: Average loss: 0.000733
#
# Epoch: 732
#
# Test set: Average loss: 0.000737
#
# Epoch: 733
#
# Test set: Average loss: 0.000689
#
# Epoch: 734
#
# Test set: Average loss: 0.000700
#
# Epoch: 735
#
# Test set: Average loss: 0.000696
#
# Epoch: 736
#
# Test set: Average loss: 0.000721
#
# Epoch: 737
#
# Test set: Average loss: 0.000703
#
# Epoch: 738
#
# Test set: Average loss: 0.000687
#
# Epoch: 739
#
# Test set: Average loss: 0.000706
#
# Epoch: 740
#
# Test set: Average loss: 0.000687
#
# Epoch: 741
#
# Test set: Average loss: 0.000680
#
# Epoch: 742
#
# Test set: Average loss: 0.000699
#
# Epoch: 743
#
# Test set: Average loss: 0.000701
#
# Epoch: 744
#
# Test set: Average loss: 0.000703
#
# Epoch: 745
#
# Test set: Average loss: 0.000705
#
# Epoch: 746
#
# Test set: Average loss: 0.000701
#
# Epoch: 747
#
# Test set: Average loss: 0.000698
#
# Epoch: 748
#
# Test set: Average loss: 0.000683
#
# Epoch: 749
#
# Test set: Average loss: 0.000683
#
# Epoch: 750
#
# Test set: Average loss: 0.000690
#
# Epoch: 751
#
# Test set: Average loss: 0.000704
#
# Epoch: 752
#
# Test set: Average loss: 0.000701
#
# Epoch: 753
#
# Test set: Average loss: 0.000670
#
# Epoch: 754
#
# Test set: Average loss: 0.000670
#
# Epoch: 755
#
# Test set: Average loss: 0.000652
#
# Epoch: 756
#
# Test set: Average loss: 0.000684
#
# Epoch: 757
#
# Test set: Average loss: 0.000660
#
# Epoch: 758
#
# Test set: Average loss: 0.000682
#
# Epoch: 759
#
# Test set: Average loss: 0.000665
#
# Epoch: 760
#
# Test set: Average loss: 0.000685
#
# Epoch: 761
#
# Test set: Average loss: 0.000660
#
# Epoch: 762
#
# Test set: Average loss: 0.000664
#
# Epoch: 763
#
# Test set: Average loss: 0.000693
#
# Epoch: 764
#
# Test set: Average loss: 0.000631
#
# Epoch: 765
#
# Test set: Average loss: 0.000675
#
# Epoch: 766
#
# Test set: Average loss: 0.000671
#
# Epoch: 767
#
# Test set: Average loss: 0.000681
#
# Epoch: 768
#
# Test set: Average loss: 0.000659
#
# Epoch: 769
#
# Test set: Average loss: 0.000650
#
# Epoch: 770
#
# Test set: Average loss: 0.000641
#
# Epoch: 771
#
# Test set: Average loss: 0.000667
#
# Epoch: 772
#
# Test set: Average loss: 0.000658
#
# Epoch: 773
#
# Test set: Average loss: 0.000680
#
# Epoch: 774
#
# Test set: Average loss: 0.000671
#
# Epoch: 775
#
# Test set: Average loss: 0.000636
#
# Epoch: 776
#
# Test set: Average loss: 0.000651
#
# Epoch: 777
#
# Test set: Average loss: 0.000645
#
# Epoch: 778
#
# Test set: Average loss: 0.000673
#
# Epoch: 779
#
# Test set: Average loss: 0.000636
#
# Epoch: 780
#
# Test set: Average loss: 0.000632
#
# Epoch: 781
#
# Test set: Average loss: 0.000671
#
# Epoch: 782
#
# Test set: Average loss: 0.000639
#
# Epoch: 783
#
# Test set: Average loss: 0.000630
#
# Epoch: 784
#
# Test set: Average loss: 0.000628
#
# Epoch: 785
#
# Test set: Average loss: 0.000621
#
# Epoch: 786
#
# Test set: Average loss: 0.000614
#
# Epoch: 787
#
# Test set: Average loss: 0.000616
#
# Epoch: 788
#
# Test set: Average loss: 0.000606
#
# Epoch: 789
#
# Test set: Average loss: 0.000628
#
# Epoch: 790
#
# Test set: Average loss: 0.000614
#
# Epoch: 791
#
# Test set: Average loss: 0.000591
#
# Epoch: 792
#
# Test set: Average loss: 0.000615
#
# Epoch: 793
#
# Test set: Average loss: 0.000623
#
# Epoch: 794
#
# Test set: Average loss: 0.000622
#
# Epoch: 795
#
# Test set: Average loss: 0.000593
#
# Epoch: 796
#
# Test set: Average loss: 0.000614
#
# Epoch: 797
#
# Test set: Average loss: 0.000598
#
# Epoch: 798
#
# Test set: Average loss: 0.000611
#
# Epoch: 799
#
# Test set: Average loss: 0.000609
#
# Epoch: 800
#
# Test set: Average loss: 0.000626
#
# Epoch: 801
#
# Test set: Average loss: 0.000582
#
# Epoch: 802
#
# Test set: Average loss: 0.000617
#
# Epoch: 803
#
# Test set: Average loss: 0.000596
#
# Epoch: 804
#
# Test set: Average loss: 0.000626
#
# Epoch: 805
#
# Test set: Average loss: 0.000592
#
# Epoch: 806
#
# Test set: Average loss: 0.000569
#
# Epoch: 807
#
# Test set: Average loss: 0.000591
#
# Epoch: 808
#
# Test set: Average loss: 0.000602
#
# Epoch: 809
#
# Test set: Average loss: 0.000598
#
# Epoch: 810
#
# Test set: Average loss: 0.000614
#
# Epoch: 811
#
# Test set: Average loss: 0.000598
#
# Epoch: 812
#
# Test set: Average loss: 0.000591
#
# Epoch: 813
#
# Test set: Average loss: 0.000568
#
# Epoch: 814
#
# Test set: Average loss: 0.000584
#
# Epoch: 815
#
# Test set: Average loss: 0.000600
#
# Epoch: 816
#
# Test set: Average loss: 0.000580
#
# Epoch: 817
#
# Test set: Average loss: 0.000587
#
# Epoch: 818
#
# Test set: Average loss: 0.000597
#
# Epoch: 819
#
# Test set: Average loss: 0.000576
#
# Epoch: 820
#
# Test set: Average loss: 0.000567
#
# Epoch: 821
#
# Test set: Average loss: 0.000568
#
# Epoch: 822
#
# Test set: Average loss: 0.000586
#
# Epoch: 823
#
# Test set: Average loss: 0.000561
#
# Epoch: 824
#
# Test set: Average loss: 0.000571
#
# Epoch: 825
#
# Test set: Average loss: 0.000555
#
# Epoch: 826
#
# Test set: Average loss: 0.000576
#
# Epoch: 827
#
# Test set: Average loss: 0.000574
#
# Epoch: 828
#
# Test set: Average loss: 0.000550
#
# Epoch: 829
#
# Test set: Average loss: 0.000568
#
# Epoch: 830
#
# Test set: Average loss: 0.000548
#
# Epoch: 831
#
# Test set: Average loss: 0.000557
#
# Epoch: 832
#
# Test set: Average loss: 0.000536
#
# Epoch: 833
#
# Test set: Average loss: 0.000557
#
# Epoch: 834
#
# Test set: Average loss: 0.000564
#
# Epoch: 835
#
# Test set: Average loss: 0.000557
#
# Epoch: 836
#
# Test set: Average loss: 0.000573
#
# Epoch: 837
#
# Test set: Average loss: 0.000548
#
# Epoch: 838
#
# Test set: Average loss: 0.000539
#
# Epoch: 839
#
# Test set: Average loss: 0.000559
#
# Epoch: 840
#
# Test set: Average loss: 0.000562
#
# Epoch: 841
#
# Test set: Average loss: 0.000529
#
# Epoch: 842
#
# Test set: Average loss: 0.000558
#
# Epoch: 843
#
# Test set: Average loss: 0.000548
#
# Epoch: 844
#
# Test set: Average loss: 0.000549
#
# Epoch: 845
#
# Test set: Average loss: 0.000544
#
# Epoch: 846
#
# Test set: Average loss: 0.000551
#
# Epoch: 847
#
# Test set: Average loss: 0.000559
#
# Epoch: 848
#
# Test set: Average loss: 0.000544
#
# Epoch: 849
#
# Test set: Average loss: 0.000537
#
# Epoch: 850
#
# Test set: Average loss: 0.000533
#
# Epoch: 851
#
# Test set: Average loss: 0.000524
#
# Epoch: 852
#
# Test set: Average loss: 0.000533
#
# Epoch: 853
#
# Test set: Average loss: 0.000542
#
# Epoch: 854
#
# Test set: Average loss: 0.000535
#
# Epoch: 855
#
# Test set: Average loss: 0.000510
#
# Epoch: 856
#
# Test set: Average loss: 0.000536
#
# Epoch: 857
#
# Test set: Average loss: 0.000511
#
# Epoch: 858
#
# Test set: Average loss: 0.000508
#
# Epoch: 859
#
# Test set: Average loss: 0.000512
#
# Epoch: 860
#
# Test set: Average loss: 0.000515
#
# Epoch: 861
#
# Test set: Average loss: 0.000496
#
# Epoch: 862
#
# Test set: Average loss: 0.000508
#
# Epoch: 863
#
# Test set: Average loss: 0.000539
#
# Epoch: 864
#
# Test set: Average loss: 0.000506
#
# Epoch: 865
#
# Test set: Average loss: 0.000521
#
# Epoch: 866
#
# Test set: Average loss: 0.000492
#
# Epoch: 867
#
# Test set: Average loss: 0.000497
#
# Epoch: 868
#
# Test set: Average loss: 0.000477
#
# Epoch: 869
#
# Test set: Average loss: 0.000473
#
# Epoch: 870
#
# Test set: Average loss: 0.000502
#
# Epoch: 871
#
# Test set: Average loss: 0.000513
#
# Epoch: 872
#
# Test set: Average loss: 0.000483
#
# Epoch: 873
#
# Test set: Average loss: 0.000492
#
# Epoch: 874
#
# Test set: Average loss: 0.000494
#
# Epoch: 875
#
# Test set: Average loss: 0.000490
#
# Epoch: 876
#
# Test set: Average loss: 0.000462
#
# Epoch: 877
#
# Test set: Average loss: 0.000476
#
# Epoch: 878
#
# Test set: Average loss: 0.000483
#
# Epoch: 879
#
# Test set: Average loss: 0.000464
#
# Epoch: 880
#
# Test set: Average loss: 0.000473
#
# Epoch: 881
#
# Test set: Average loss: 0.000470
#
# Epoch: 882
#
# Test set: Average loss: 0.000455
#
# Epoch: 883
#
# Test set: Average loss: 0.000479
#
# Epoch: 884
#
# Test set: Average loss: 0.000477
#
# Epoch: 885
#
# Test set: Average loss: 0.000499
#
# Epoch: 886
#
# Test set: Average loss: 0.000454
#
# Epoch: 887
#
# Test set: Average loss: 0.000472
#
# Epoch: 888
#
# Test set: Average loss: 0.000446
#
# Epoch: 889
#
# Test set: Average loss: 0.000447
#
# Epoch: 890
#
# Test set: Average loss: 0.000478
#
# Epoch: 891
#
# Test set: Average loss: 0.000478
#
# Epoch: 892
#
# Test set: Average loss: 0.000474
#
# Epoch: 893
#
# Test set: Average loss: 0.000437
#
# Epoch: 894
#
# Test set: Average loss: 0.000467
#
# Epoch: 895
#
# Test set: Average loss: 0.000445
# Epoch: 896
#
# Test set: Average loss: 0.000464
#
# Epoch: 897
#
# Test set: Average loss: 0.000462
#
# Epoch: 898
#
# Test set: Average loss: 0.000466
#
# Epoch: 899
#
# Test set: Average loss: 0.000432
#
# Epoch: 900
#
# Test set: Average loss: 0.000461
#
# Epoch: 901
#
# Test set: Average loss: 0.000465
#
# Epoch: 902
#
# Test set: Average loss: 0.000459
#
# Epoch: 903
#
# Test set: Average loss: 0.000450
#
# Epoch: 904
#
# Test set: Average loss: 0.000461
#
# Epoch: 905
#
# Test set: Average loss: 0.000455
#
# Epoch: 906
#
# Test set: Average loss: 0.000449
#
# Epoch: 907
#
# Test set: Average loss: 0.000435
#
# Epoch: 908
#
# Test set: Average loss: 0.000447
#
# Epoch: 909
#
# Test set: Average loss: 0.000431
#
# Epoch: 910
#
# Test set: Average loss: 0.000447
#
# Epoch: 911
#
# Test set: Average loss: 0.000443
#
# Epoch: 912
#
# Test set: Average loss: 0.000441
#
# Epoch: 913
#
# Test set: Average loss: 0.000423
#
# Epoch: 914
#
# Test set: Average loss: 0.000448
#
# Epoch: 915
#
# Test set: Average loss: 0.000452
#
# Epoch: 916
#
# Test set: Average loss: 0.000436
#
# Epoch: 917
#
# Test set: Average loss: 0.000433
#
# Epoch: 918
#
# Test set: Average loss: 0.000432
#
# Epoch: 919
#
# Test set: Average loss: 0.000443
#
# Epoch: 920
#
# Test set: Average loss: 0.000451
#
# Epoch: 921
#
# Test set: Average loss: 0.000421
#
# Epoch: 922
#
# Test set: Average loss: 0.000433
#
# Epoch: 923
#
# Test set: Average loss: 0.000406
#
# Epoch: 924
#
# Test set: Average loss: 0.000414
#
# Epoch: 925
#
# Test set: Average loss: 0.000416
#
# Epoch: 926
#
# Test set: Average loss: 0.000430
#
# Epoch: 927
#
# Test set: Average loss: 0.000419
#
# Epoch: 928
#
# Test set: Average loss: 0.000422
#
# Epoch: 929
#
# Test set: Average loss: 0.000414
#
# Epoch: 930
#
# Test set: Average loss: 0.000431
#
# Epoch: 931
#
# Test set: Average loss: 0.000437
#
# Epoch: 932
#
# Test set: Average loss: 0.000425
#
# Epoch: 933
#
# Test set: Average loss: 0.000419
#
# Epoch: 934
#
# Test set: Average loss: 0.000418
#
# Epoch: 935
#
# Test set: Average loss: 0.000396
#
# Epoch: 936
#
# Test set: Average loss: 0.000413
#
# Epoch: 937
#
# Test set: Average loss: 0.000413
#
# Epoch: 938
#
# Test set: Average loss: 0.000405
#
# Epoch: 939
#
# Test set: Average loss: 0.000408
#
# Epoch: 940
#
# Test set: Average loss: 0.000402
#
# Epoch: 941
#
# Test set: Average loss: 0.000400
#
# Epoch: 942
#
# Test set: Average loss: 0.000414
#
# Epoch: 943
#
# Test set: Average loss: 0.000418
#
# Epoch: 944
#
# Test set: Average loss: 0.000403
#
# Epoch: 945
#
# Test set: Average loss: 0.000423
#
# Epoch: 946
#
# Test set: Average loss: 0.000421
#
# Epoch: 947
#
# Test set: Average loss: 0.000388
#
# Epoch: 948
#
# Test set: Average loss: 0.000409
#
# Epoch: 949
#
# Test set: Average loss: 0.000398
#
# Epoch: 950
#
# Test set: Average loss: 0.000401
#
# Epoch: 951
#
# Test set: Average loss: 0.000411
#
# Epoch: 952
#
# Test set: Average loss: 0.000413
#
# Epoch: 953
#
# Test set: Average loss: 0.000406
#
# Epoch: 954
#
# Test set: Average loss: 0.000402
#
# Epoch: 955
#
# Test set: Average loss: 0.000386
#
# Epoch: 956
#
# Test set: Average loss: 0.000371
#
# Epoch: 957
#
# Test set: Average loss: 0.000384
#
# Epoch: 958
#
# Test set: Average loss: 0.000385
#
# Epoch: 959
#
# Test set: Average loss: 0.000403
#
# Epoch: 960
#
# Test set: Average loss: 0.000395
#
# Epoch: 961
#
# Test set: Average loss: 0.000374
#
# Epoch: 962
#
# Test set: Average loss: 0.000376
#
# Epoch: 963
#
# Test set: Average loss: 0.000382
#
# Epoch: 964
#
# Test set: Average loss: 0.000403
#
# Epoch: 965
#
# Test set: Average loss: 0.000378
#
# Epoch: 966
#
# Test set: Average loss: 0.000387
#
# Epoch: 967
#
# Test set: Average loss: 0.000380
#
# Epoch: 968
#
# Test set: Average loss: 0.000381
#
# Epoch: 969
#
# Test set: Average loss: 0.000372
#
# Epoch: 970
#
# Test set: Average loss: 0.000381
#
# Epoch: 971
#
# Test set: Average loss: 0.000384
#
# Epoch: 972
#
# Test set: Average loss: 0.000391
#
# Epoch: 973
#
# Test set: Average loss: 0.000376
#
# Epoch: 974
#
# Test set: Average loss: 0.000367
#
# Epoch: 975
#
# Test set: Average loss: 0.000373
#
# Epoch: 976
#
# Test set: Average loss: 0.000386
#
# Epoch: 977
#
# Test set: Average loss: 0.000366
#
# Epoch: 978
#
# Test set: Average loss: 0.000349
#
# Epoch: 979
#
# Test set: Average loss: 0.000375
#
# Epoch: 980
#
# Test set: Average loss: 0.000378
#
# Epoch: 981
#
# Test set: Average loss: 0.000377
#
# Epoch: 982
#
# Test set: Average loss: 0.000383
#
# Epoch: 983
#
# Test set: Average loss: 0.000354
#
# Epoch: 984
#
# Test set: Average loss: 0.000364
#
# Epoch: 985
#
# Test set: Average loss: 0.000356
#
# Epoch: 986
#
# Test set: Average loss: 0.000374
#
# Epoch: 987
#
# Test set: Average loss: 0.000353
#
# Epoch: 988
#
# Test set: Average loss: 0.000360
#
# Epoch: 989
#
# Test set: Average loss: 0.000374
#
# Epoch: 990
#
# Test set: Average loss: 0.000390
#
# Epoch: 991
#
# Test set: Average loss: 0.000362
#
# Epoch: 992
#
# Test set: Average loss: 0.000356
#
# Epoch: 993
#
# Test set: Average loss: 0.000357
#
# Epoch: 994
#
# Test set: Average loss: 0.000347
#
# Epoch: 995
#
# Test set: Average loss: 0.000343
#
# Epoch: 996
#
# Test set: Average loss: 0.000363
#
# Epoch: 997
#
# Test set: Average loss: 0.000356
#
# Epoch: 998
#
# Test set: Average loss: 0.000356
#
# Epoch: 999
#
# Test set: Average loss: 0.000345
#
# Epoch: 1000
#
# Test set: Average loss: 0.000350
#
# Epoch: 1001
#
# Test set: Average loss: 0.000340
#
# Epoch: 1002
#
# Test set: Average loss: 0.000350
#
# Epoch: 1003
#
# Test set: Average loss: 0.000355
#
# Epoch: 1004
#
# Test set: Average loss: 0.000363
#
# Epoch: 1005
#
# Test set: Average loss: 0.000362
#
# Epoch: 1006
#
# Test set: Average loss: 0.000346
#
# Epoch: 1007
#
# Test set: Average loss: 0.000358
#
# Epoch: 1008
#
# Test set: Average loss: 0.000349
#
# Epoch: 1009
#
# Test set: Average loss: 0.000347
#
# Epoch: 1010
#
# Test set: Average loss: 0.000354
#
# Epoch: 1011
#
# Test set: Average loss: 0.000361
#
# Epoch: 1012
#
# Test set: Average loss: 0.000376
#
# Epoch: 1013
#
# Test set: Average loss: 0.000337
#
# Epoch: 1014
#
# Test set: Average loss: 0.000323
#
# Epoch: 1015
#
# Test set: Average loss: 0.000349
#
# Epoch: 1016
#
# Test set: Average loss: 0.000346
#
# Epoch: 1017
#
# Test set: Average loss: 0.000336
#
# Epoch: 1018
#
# Test set: Average loss: 0.000343
#
# Epoch: 1019
#
# Test set: Average loss: 0.000342
#
# Epoch: 1020
#
# Test set: Average loss: 0.000330
#
# Epoch: 1021
#
# Test set: Average loss: 0.000328
#
# Epoch: 1022
#
# Test set: Average loss: 0.000349
#
# Epoch: 1023
#
# Test set: Average loss: 0.000326
#
# Epoch: 1024
#
# Test set: Average loss: 0.000324
#
# Epoch: 1025
#
# Test set: Average loss: 0.000332
#
# Epoch: 1026
#
# Test set: Average loss: 0.000326
#
# Epoch: 1027
#
# Test set: Average loss: 0.000341
#
# Epoch: 1028
#
# Test set: Average loss: 0.000332
#
# Epoch: 1029
#
# Test set: Average loss: 0.000333
#
# Epoch: 1030
#
# Test set: Average loss: 0.000333
#
# Epoch: 1031
#
# Test set: Average loss: 0.000330
#
# Epoch: 1032
#
# Test set: Average loss: 0.000334
#
# Epoch: 1033
#
# Test set: Average loss: 0.000314
#
# Epoch: 1034
#
# Test set: Average loss: 0.000332
#
# Epoch: 1035
#
# Test set: Average loss: 0.000326
#
# Epoch: 1036
#
# Test set: Average loss: 0.000324
#
# Epoch: 1037
#
# Test set: Average loss: 0.000323
#
# Epoch: 1038
#
# Test set: Average loss: 0.000307
#
# Epoch: 1039
#
# Test set: Average loss: 0.000306
#
# Epoch: 1040
#
# Test set: Average loss: 0.000321
#
# Epoch: 1041
#
# Test set: Average loss: 0.000320
#
# Epoch: 1042
#
# Test set: Average loss: 0.000309
#
# Epoch: 1043
#
# Test set: Average loss: 0.000315
#
# Epoch: 1044
#
# Test set: Average loss: 0.000338
#
# Epoch: 1045
#
# ...
# Test set: Average loss: 0.000035
#
# Epoch: 15227
#
# Test set: Average loss: 0.000033
#
# Epoch: 15228
#
# Test set: Average loss: 0.000032
#
# Epoch: 15229
#
# Test set: Average loss: 0.000032
#
# Epoch: 15230
#
# Test set: Average loss: 0.000032
#
# Epoch: 15231
#
# Test set: Average loss: 0.000034
#
# Epoch: 15232
#
# Test set: Average loss: 0.000033
#
# Epoch: 15233
#
# Test set: Average loss: 0.000035
#
# Epoch: 15234
#
# Test set: Average loss: 0.000032
#
# Epoch: 15235
#
# Test set: Average loss: 0.000033
#
# Epoch: 15236
#
# Test set: Average loss: 0.000032
#
# Epoch: 15237
#
# Test set: Average loss: 0.000032
#
# Epoch: 15238
#
# Test set: Average loss: 0.000033
#
# Epoch: 15239
#
# Test set: Average loss: 0.000034
#
# Epoch: 15240
#
# Test set: Average loss: 0.000029
#
# Epoch: 15241
#
# Test set: Average loss: 0.000033
#
# Epoch: 15242
#
# Test set: Average loss: 0.000032
#
# Epoch: 15243
#
# Test set: Average loss: 0.000031
#
# Epoch: 15244
#
# Test set: Average loss: 0.000033
#
# Epoch: 15245
#
# Test set: Average loss: 0.000035
#
# Epoch: 15246
#
# Test set: Average loss: 0.000036
#
# Epoch: 15247
#
# Test set: Average loss: 0.000033
#
# Epoch: 15248
#
# Test set: Average loss: 0.000034
#
# Epoch: 15249
#
# Test set: Average loss: 0.000036
#
# Epoch: 15250
#
# Test set: Average loss: 0.000037
#
# Epoch: 15251
#
# Test set: Average loss: 0.000033
#
# Epoch: 15252
#
# Test set: Average loss: 0.000033
#
# Epoch: 15253
#
# Test set: Average loss: 0.000032
#
# Epoch: 15254
#
# Test set: Average loss: 0.000032
#
# Epoch: 15255
#
# Test set: Average loss: 0.000035
#
# Epoch: 15256
#
# Test set: Average loss: 0.000033
#
# Epoch: 15257
#
# Test set: Average loss: 0.000035
#
# Epoch: 15258
#
# Test set: Average loss: 0.000033
#
# Epoch: 15259
#
# Test set: Average loss: 0.000033
#
# Epoch: 15260
#
# Test set: Average loss: 0.000032
#
# Epoch: 15261
#
# Test set: Average loss: 0.000034
#
# Epoch: 15262
#
# Test set: Average loss: 0.000031
#
# Epoch: 15263
#
# Test set: Average loss: 0.000034
#
# Epoch: 15264
#
# Test set: Average loss: 0.000036
#
# Epoch: 15265
#
# Test set: Average loss: 0.000031
#
# Epoch: 15266
#
# Test set: Average loss: 0.000032
#
# Epoch: 15267
#
# Test set: Average loss: 0.000034
#
# Epoch: 15268
#
# Test set: Average loss: 0.000033
#
# Epoch: 15269
#
# Test set: Average loss: 0.000033
#
# Epoch: 15270
#
# Test set: Average loss: 0.000032
#
# Epoch: 15271
#
# Test set: Average loss: 0.000031
#
# Epoch: 15272
#
# Test set: Average loss: 0.000034
#
# Epoch: 15273
#
# Test set: Average loss: 0.000034
#
# Epoch: 15274
#
# Test set: Average loss: 0.000033
#
# Epoch: 15275
#
# Test set: Average loss: 0.000031
#
# Epoch: 15276
#
# Test set: Average loss: 0.000032
#
# Epoch: 15277
#
# Test set: Average loss: 0.000034
#
# Epoch: 15278
#
# Test set: Average loss: 0.000033
#
# Epoch: 15279
#
# Test set: Average loss: 0.000033
#
# Epoch: 15280
#
# Test set: Average loss: 0.000032
#
# Epoch: 15281
#
# Test set: Average loss: 0.000031
#
# Epoch: 15282
#
# Test set: Average loss: 0.000035
#
# Epoch: 15283
#
# Test set: Average loss: 0.000032
#
# Epoch: 15284
#
# Test set: Average loss: 0.000033
#
# Epoch: 15285
#
# Test set: Average loss: 0.000031
#
# Epoch: 15286
#
# Test set: Average loss: 0.000037
#
# Epoch: 15287
#
# Test set: Average loss: 0.000032
#
# Epoch: 15288
#
# Test set: Average loss: 0.000033
#
# Epoch: 15289
#
# Test set: Average loss: 0.000033
#
# Epoch: 15290
#
# Test set: Average loss: 0.000033
#
# Epoch: 15291
#
# Test set: Average loss: 0.000031
#
# Epoch: 15292
#
# Test set: Average loss: 0.000033
#
# Epoch: 15293
#
# Test set: Average loss: 0.000035
#
# Epoch: 15294
#
# Test set: Average loss: 0.000030
#
# Epoch: 15295
#
# Test set: Average loss: 0.000033
#
# Epoch: 15296
#
# Test set: Average loss: 0.000035
#
# Epoch: 15297
#
# Test set: Average loss: 0.000036
#
# Epoch: 15298
#
# Test set: Average loss: 0.000031
# Epoch: 15299
#
# Test set: Average loss: 0.000034
#
# Epoch: 15300
#
# Test set: Average loss: 0.000033
#
# Epoch: 15301
#
# Test set: Average loss: 0.000030
#
# Epoch: 15302
#
# Test set: Average loss: 0.000032
#
# Epoch: 15303
#
# Test set: Average loss: 0.000033
#
# Epoch: 15304
#
# Test set: Average loss: 0.000031
#
# Epoch: 15305
#
# Test set: Average loss: 0.000032
#
# Epoch: 15306
#
# Test set: Average loss: 0.000030
#
# Epoch: 15307
#
# Test set: Average loss: 0.000032
#
# Epoch: 15308
#
# Test set: Average loss: 0.000033
#
# Epoch: 15309
#
# Test set: Average loss: 0.000033
#
# Epoch: 15310
#
# Test set: Average loss: 0.000031
#
# Epoch: 15311
#
# Test set: Average loss: 0.000033
#
# Epoch: 15312
#
# Test set: Average loss: 0.000030
#
# Epoch: 15313
#
# Test set: Average loss: 0.000032
#
# Epoch: 15314
#
# Test set: Average loss: 0.000032
#
# Epoch: 15315
#
# Test set: Average loss: 0.000031
#
# Epoch: 15316
#
# Test set: Average loss: 0.000034
#
# Epoch: 15317
#
# Test set: Average loss: 0.000032
#
# Epoch: 15318
#
# Test set: Average loss: 0.000033
#
# Epoch: 15319
#
# Test set: Average loss: 0.000033
#
# Epoch: 15320
#
# Test set: Average loss: 0.000032
#
# Epoch: 15321
#
# Test set: Average loss: 0.000036
#
# Epoch: 15322
#
# Test set: Average loss: 0.000031
#
# Epoch: 15323
#
# Test set: Average loss: 0.000035
#
# Epoch: 15324
#
# Test set: Average loss: 0.000033
#
# Epoch: 15325
#
# Test set: Average loss: 0.000030
#
# Epoch: 15326
#
# Test set: Average loss: 0.000032
#
# Epoch: 15327
#
# Test set: Average loss: 0.000031
#
# Epoch: 15328
#
# Test set: Average loss: 0.000029
#
# Epoch: 15329
#
# Test set: Average loss: 0.000031
#
# Epoch: 15330
#
# Test set: Average loss: 0.000032
#
# Epoch: 15331
#
# Test set: Average loss: 0.000032
#
# Epoch: 15332
#
# Test set: Average loss: 0.000031
#
# Epoch: 15333
#
# Test set: Average loss: 0.000032
#
# Epoch: 15334
#
# Test set: Average loss: 0.000033
#
# Epoch: 15335
#
# Test set: Average loss: 0.000034
#
# Epoch: 15336
#
# Test set: Average loss: 0.000031
#
# Epoch: 15337
#
# Test set: Average loss: 0.000033
#
# Epoch: 15338
#
# Test set: Average loss: 0.000032
#
# Epoch: 15339
#
# Test set: Average loss: 0.000033
#
# Epoch: 15340
#
# Test set: Average loss: 0.000031
#
# Epoch: 15341
#
# Test set: Average loss: 0.000029
#
# Epoch: 15342
#
# Test set: Average loss: 0.000032
#
# Epoch: 15343
#
# Test set: Average loss: 0.000033
#
# Epoch: 15344
#
# Test set: Average loss: 0.000034
#
# Epoch: 15345
#
# Test set: Average loss: 0.000030
#
# Epoch: 15346
#
# Test set: Average loss: 0.000035
#
# Epoch: 15347
#
# Test set: Average loss: 0.000030
#
# Epoch: 15348
#
# Test set: Average loss: 0.000033
#
# Epoch: 15349
#
# Test set: Average loss: 0.000033
#
# Epoch: 15350
#
# Test set: Average loss: 0.000033
#
# Epoch: 15351
#
# Test set: Average loss: 0.000032
#
# Epoch: 15352
#
# Test set: Average loss: 0.000030
#
# Epoch: 15353
#
# Test set: Average loss: 0.000034
#
# Epoch: 15354
#
# Test set: Average loss: 0.000032
#
# Epoch: 15355
#
# Test set: Average loss: 0.000032
#
# Epoch: 15356
#
# Test set: Average loss: 0.000032
#
# Epoch: 15357
#
# Test set: Average loss: 0.000031
#
# Epoch: 15358
#
# Test set: Average loss: 0.000031
#
# Epoch: 15359
#
# Test set: Average loss: 0.000032
#
# Epoch: 15360
#
# Test set: Average loss: 0.000033
#
# Epoch: 15361
#
# Test set: Average loss: 0.000034
#
# Epoch: 15362
#
# Test set: Average loss: 0.000035
#
# Epoch: 15363
#
# Test set: Average loss: 0.000033
#
# Epoch: 15364
#
# Test set: Average loss: 0.000034
#
# Epoch: 15365
#
# Test set: Average loss: 0.000032
#
# Epoch: 15366
#
# Test set: Average loss: 0.000034
#
# Epoch: 15367
#
# Test set: Average loss: 0.000031
#
# Epoch: 15368
#
# Test set: Average loss: 0.000034
#
# Epoch: 15369
#
# Test set: Average loss: 0.000033
#
# Epoch: 15370
#
# Test set: Average loss: 0.000033
#
# Epoch: 15371
#
# Test set: Average loss: 0.000031
#
# Epoch: 15372
#
# Test set: Average loss: 0.000032
#
# Epoch: 15373
#
# Test set: Average loss: 0.000035
#
# Epoch: 15374
#
# Test set: Average loss: 0.000031
#
# Epoch: 15375
#
# Test set: Average loss: 0.000031
#
# Epoch: 15376
#
# Test set: Average loss: 0.000031
#
# Epoch: 15377
#
# Test set: Average loss: 0.000031
#
# Epoch: 15378
#
# Test set: Average loss: 0.000031
#
# Epoch: 15379
#
# Test set: Average loss: 0.000031
#
# Epoch: 15380
#
# Test set: Average loss: 0.000032
#
# Epoch: 15381
#
# Test set: Average loss: 0.000031
#
# Epoch: 15382
#
# Test set: Average loss: 0.000035
#
# Epoch: 15383
#
# Test set: Average loss: 0.000030
#
# Epoch: 15384
#
# Test set: Average loss: 0.000034
#
# Epoch: 15385
#
# Test set: Average loss: 0.000034
#
# Epoch: 15386
#
# Test set: Average loss: 0.000031
#
# Epoch: 15387
#
# Test set: Average loss: 0.000033
#
# Epoch: 15388
#
# Test set: Average loss: 0.000034
#
# Epoch: 15389
#
# Test set: Average loss: 0.000035
#
# Epoch: 15390
#
# Test set: Average loss: 0.000033
#
# Epoch: 15391
#
# Test set: Average loss: 0.000032
#
# Epoch: 15392
#
# Test set: Average loss: 0.000032
#
# Epoch: 15393
#
# Test set: Average loss: 0.000033
#
# Epoch: 15394
#
# Test set: Average loss: 0.000033
#
# Epoch: 15395
#
# Test set: Average loss: 0.000031
#
# Epoch: 15396
#
# Test set: Average loss: 0.000033
#
# Epoch: 15397
#
# Test set: Average loss: 0.000031
#
# Epoch: 15398
#
# Test set: Average loss: 0.000030
#
# Epoch: 15399
#
# Test set: Average loss: 0.000031
#
# Epoch: 15400
#
# Test set: Average loss: 0.000030
#
# Epoch: 15401
#
# Test set: Average loss: 0.000033
#
# Epoch: 15402
#
# Test set: Average loss: 0.000032
#
# Epoch: 15403
#
# Test set: Average loss: 0.000033
#
# Epoch: 15404
#
# Test set: Average loss: 0.000032
#
# Epoch: 15405
#
# Test set: Average loss: 0.000036
#
# Epoch: 15406
#
# Test set: Average loss: 0.000030
#
# Epoch: 15407
#
# Test set: Average loss: 0.000033
#
# Epoch: 15408
#
# Test set: Average loss: 0.000035
#
# Epoch: 15409
#
# Test set: Average loss: 0.000032
#
# Epoch: 15410
#
# Test set: Average loss: 0.000032
#
# Epoch: 15411
#
# Test set: Average loss: 0.000033
#
# Epoch: 15412
#
# Test set: Average loss: 0.000032
#
# Epoch: 15413
#
# Test set: Average loss: 0.000034
#
# Epoch: 15414
#
# Test set: Average loss: 0.000032
#
# Epoch: 15415
#
# Test set: Average loss: 0.000033
#
# Epoch: 15416
#
# Test set: Average loss: 0.000034
#
# Epoch: 15417
#
# Test set: Average loss: 0.000035
#
# Epoch: 15418
#
# Test set: Average loss: 0.000035
#
# Epoch: 15419
#
# Test set: Average loss: 0.000034
#
# Epoch: 15420
#
# Test set: Average loss: 0.000034
#
# Epoch: 15421
#
# Test set: Average loss: 0.000030
#
# Epoch: 15422
#
# Test set: Average loss: 0.000034
#
# Epoch: 15423
#
# Test set: Average loss: 0.000032
#
# Epoch: 15424
#
# Test set: Average loss: 0.000033
#
# Epoch: 15425
#
# Test set: Average loss: 0.000031
#
# Epoch: 15426
#
# Test set: Average loss: 0.000033
#
# Epoch: 15427
#
# Test set: Average loss: 0.000031
#
# Epoch: 15428
#
# Test set: Average loss: 0.000033
#
# Epoch: 15429
#
# Test set: Average loss: 0.000033
#
# Epoch: 15430
#
# Test set: Average loss: 0.000033
#
# Epoch: 15431
#
# Test set: Average loss: 0.000030
#
# Epoch: 15432
#
# Test set: Average loss: 0.000031
#
# Epoch: 15433
#
# Test set: Average loss: 0.000030
#
# Epoch: 15434
#
# Test set: Average loss: 0.000033
#
# Epoch: 15435
#
# Test set: Average loss: 0.000032
#
# Epoch: 15436
#
# Test set: Average loss: 0.000031
#
# Epoch: 15437
#
# Test set: Average loss: 0.000036
#
# Epoch: 15438
#
# Test set: Average loss: 0.000032
#
# Epoch: 15439
#
# Test set: Average loss: 0.000033
#
# Epoch: 15440
#
# Test set: Average loss: 0.000032
#
# Epoch: 15441
#
# Test set: Average loss: 0.000033
#
# Epoch: 15442
#
# Test set: Average loss: 0.000028
#
# Epoch: 15443
#
# Test set: Average loss: 0.000033
#
# Epoch: 15444
#
# Test set: Average loss: 0.000030
#
# Epoch: 15445
#
# Test set: Average loss: 0.000030
#
# Epoch: 15446
#
# Test set: Average loss: 0.000031
#
# Epoch: 15447
#
# Test set: Average loss: 0.000032
#
# Epoch: 15448
#
# Test set: Average loss: 0.000034
#
# Epoch: 15449
#
# Test set: Average loss: 0.000031
#
# Epoch: 15450
#
# Test set: Average loss: 0.000032
#
# Epoch: 15451
#
# Test set: Average loss: 0.000030
#
# Epoch: 15452
#
# Test set: Average loss: 0.000034
#
# Epoch: 15453
#
# Test set: Average loss: 0.000030
#
# Epoch: 15454
#
# Test set: Average loss: 0.000035
#
# Epoch: 15455
#
# Test set: Average loss: 0.000035
#
# Epoch: 15456
#
# Test set: Average loss: 0.000031
#
# Epoch: 15457
#
# Test set: Average loss: 0.000035
#
# Epoch: 15458
#
# Test set: Average loss: 0.000036
#
# Epoch: 15459
#
# Test set: Average loss: 0.000032
#
# Epoch: 15460
#
# Test set: Average loss: 0.000034
#
# Epoch: 15461
#
# Test set: Average loss: 0.000032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d350c2709af3> in <module>
#       3
#       4 for ep in range(1, epochs+1):
# ----> 5     train(model, ep, x_train, y_train, batch_size)
#       6     print('Epoch: {}'.format(ep))
#       7     tloss = evaluate(model, x_val, y_val)
#
# <ipython-input-15-ac3045d38db2> in train(model, epoch, X_train, Y_train, batch_size)
#      14             x, y = X_train[i:(i+batch_size), :, :], Y_train[i:(i+batch_size)]
#      15         optimizer.zero_grad()
# ---> 16         output = model(x)
#      17
#      18         # check derivatives
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-13-65a664009e45> in forward(self, x)
#      13     def forward(self, x):
#      14         # x needs to have dimension (N, C, L) in order to be passed into CNN
# ---> 15         output = self.tcn(x).transpose(1, 2).reshape((-1, self.seq_len*self.num_channels[-1]))
#      16         output = self.linear(output).double()
#      17         return output
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-12-749de65aa13b> in forward(self, x)
#      61
#      62     def forward(self, x):
# ---> 63         return self.network(x)
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-12-749de65aa13b> in forward(self, x)
#      41
#      42     def forward(self, x):
# ---> 43         out = self.net(x)
#      44         res = x if self.downsample is None else self.downsample(x)
#      45         return self.relu(out + res)
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /opt/conda/envs/ml-latest/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     205                             self.weight, self.bias, self.stride,
#     206                             _single(0), self.dilation, self.groups)
# --> 207         return F.conv1d(input, self.weight, self.bias, self.stride,
#     208                         self.padding, self.dilation, self.groups)
#     209
#
# KeyboardInterrupt:

# %%
ypred = model(x_val)

plt.figure(figsize = (16, 8))
ylbl = ['$Displacement, in$', '$Velocity, in/s$', '$Acceleration, in/s^2$']

for ii in range(3):
    plt.subplot(3,1,ii+1)
    plt.plot(t[:len(x_val)], y_val[:,ii], linewidth = 3, alpha = 0.5)
    plt.plot(t[:len(x_val)], ypred.detach().numpy()[:,ii], 'k--')

    plt.ylabel(ylbl[ii])
    plt.xlabel('Time, s')
    
#plt.xlim([0,500])
plt.savefig('PhysicsNoRecursion_zoomed.tiff')
plt.show()

# %%
ypred.detach().numpy().shape
# Out:
# (2037, 3)

# %%
def simulate(x0, u, future):
    tw = x0.shape[-1]
    feats = x0.shape[0]

    x_ = x0.reshape((1,feats,tw))
    x = x0
    ypred = model(x_)
    
    for ii in range(1,future):

        new_pair = np.hstack([u[tw + ii][0].reshape((1,1)), ypred.detach().numpy()]).reshape((feats,-1))
        x = np.concatenate([x, new_pair], axis = -1)
        
        x_ = x[:, -tw:].reshape((1, feats, tw))
        x_ = torch.from_numpy(x_)
        ypred = model(x_.float())

    return x

# %%
x0 = x_val[0]
ypred_sim = simulate(x0, utest, 500)
ypred_sim = ypred_sim[1:,train_window:]

# %%
ypred_sim.shape
# Out:
# (3, 499)

# %%
plt.figure(figsize = (16, 8))

plt.plot(y_val, linewidth = 3, alpha = 0.5)
plt.plot(ypred_sim.T)

ylbl = ['$Displacement, in$', '$Velocity, in/s$', '$Acceleration, in/s^2$']
for ii in range(3):
    plt.subplot(3,1,ii+1)
    plt.plot(t[:500-1], y_val[:500-1,ii], linewidth = 3, alpha = 0.5)
    plt.plot(t[:500-1], ypred_sim[ii,:], 'k')


    plt.ylabel(ylbl[ii])
    plt.xlabel('Time, s')

    #plt.xlim([0,500])
plt.savefig('PhysicsWithRecursion_zoomed_tw12.tiff')
plt.show()

# %%
utest.shape
u_norm.shape
print(y_full.shape)
# Out:
# torch.Size([6987, 3])

# %%
x0 = x_full[0]
npred = x_full.shape[0] - 1
ypred_sim = simulate(x0, ufull, npred)
ypred_sim = ypred_sim[1:,train_window:]

# %%
plt.figure(figsize = (16, 8))

for ii in range(3):
    plt.subplot(3,1,ii+1)
    plt.plot(t[:npred], y_full[:-1,ii], linewidth = 3, alpha = 0.5)
    plt.plot(t[:npred-1], ypred_sim[ii,:], 'k')


    plt.ylabel(ylbl[ii])
    plt.xlabel('Time, s')

    #plt.xlim([0,npred])
    
plt.savefig('PhysicsWithRecursion_full_tw12.tiff')
plt.show()

# %%
np.save(open('yfull_physics_tw12.npy', 'wb'), ypred_sim, allow_pickle = True)

# %%
nchannels = [3, 6, 9]
nlayers = [3, 5, 7]
kernelsize = [3]

epochs = 500
batch_size = 250

hyperparams = []

for nc in nchannels:
    for nl in nlayers:
        for ks in kernelsize:
            model = TCN(input_size = 2, 
                        output_size = 1, 
                        num_channels = [nc]*nl, 
                        kernel_size = ks, 
                        seq_len = train_window, 
                        dropout = 0.1)
            print([nc]*nl)
            for ep in range(1, epochs+1):
                train(model, ep, x_train, y_train, batch_size)
                if ep % 50 == 0:
                    print('Epoch: {}'.format(ep))
                    tloss = evaluate(model, x_val, y_val)
            
            hyperparams.append([nc, nl, ks, tloss])
            print(hyperparams[-1])
            
pickle.dump(hyperparams, open('hyperparam_runs.pickle', 'wb'))
# Out:
# [3, 3, 3]
# Epoch: 50
#
# Test set: Average loss: 1.173970
#
# Epoch: 100
#
# Test set: Average loss: 1.164860
#
# Epoch: 150
#
# Test set: Average loss: 1.174647
#
# Epoch: 200
#
# Test set: Average loss: 1.169710
#
# Epoch: 250
#
# Test set: Average loss: 1.175539
#
# Epoch: 300
#
# Test set: Average loss: 1.177534
#
# Epoch: 350
#
# Test set: Average loss: 1.175668
#
# Epoch: 400
#
# Test set: Average loss: 1.165821
#
# Epoch: 450
#
# Test set: Average loss: 1.174930
#
# Epoch: 500
#
# Test set: Average loss: 1.190137
#
# [3, 3, 3, 1.1901369514374631]
# [3, 3, 3, 3, 3]
# Epoch: 50
#
# Test set: Average loss: 0.244408
#
# Epoch: 100
#
# Test set: Average loss: 0.248154
#
# Epoch: 150
#
# Test set: Average loss: 0.246772
#
# Epoch: 200
#
# Test set: Average loss: 0.248602
#
# Epoch: 250
#
# Test set: Average loss: 0.248202
#
# Epoch: 300
#
# Test set: Average loss: 0.240986
#
# Epoch: 350
#
# Test set: Average loss: 0.247317
#
# Epoch: 400
#
# Test set: Average loss: 0.244650
#
# Epoch: 450
#
# Test set: Average loss: 0.244559
#
# Epoch: 500
#
# Test set: Average loss: 0.245608
#
# [3, 5, 3, 0.2456078039523973]
# [3, 3, 3, 3, 3, 3, 3]
# Epoch: 50
#
# Test set: Average loss: 0.510119
#
# Epoch: 100
#
# Test set: Average loss: 0.502877
#
# Epoch: 150
#
# Test set: Average loss: 0.516034
#
# Epoch: 200
#
# Test set: Average loss: 0.506113
#
# Epoch: 250
#
# Test set: Average loss: 0.505623
#
# Epoch: 300
#
# Test set: Average loss: 0.507803
#
# Epoch: 350
#
# Test set: Average loss: 0.510340
#
# Epoch: 400
#
# Test set: Average loss: 0.507740
#
# Epoch: 450
#
# Test set: Average loss: 0.508412
#
# Epoch: 500
#
# Test set: Average loss: 0.510597
#
# [3, 7, 3, 0.5105965993993377]
# [6, 6, 6]
# Epoch: 50
#
# Test set: Average loss: 0.122838
#
# Epoch: 100
#
# Test set: Average loss: 0.124930
#
# Epoch: 150
#
# Test set: Average loss: 0.121427
#
# Epoch: 200
#
# Test set: Average loss: 0.123314
#
# Epoch: 250
#
# Test set: Average loss: 0.118610
#
# Epoch: 300
#
# Test set: Average loss: 0.120825
#
# Epoch: 350
#
# Test set: Average loss: 0.120349
#
# Epoch: 400
#
# Test set: Average loss: 0.118605
#
# Epoch: 450
#
# Test set: Average loss: 0.121497
#
# Epoch: 500
#
# Test set: Average loss: 0.119734
#
# [6, 3, 3, 0.11973414125472952]
# [6, 6, 6, 6, 6]
# Epoch: 50
#
# Test set: Average loss: 0.543148
#
# Epoch: 100
#
# Test set: Average loss: 0.540903
#
# Epoch: 150
#
# Test set: Average loss: 0.544174
#
# Epoch: 200
#
# Test set: Average loss: 0.544441
#
# Epoch: 250
#
# Test set: Average loss: 0.544647
#
# Epoch: 300
#
# Test set: Average loss: 0.542672
#
# Epoch: 350
#
# Test set: Average loss: 0.547288
#
# Epoch: 400
#
# Test set: Average loss: 0.541802
#
# Epoch: 450
#
# Test set: Average loss: 0.542675
#
# Epoch: 500
#
# Test set: Average loss: 0.545826
#
# [6, 5, 3, 0.5458264064765384]
# [6, 6, 6, 6, 6, 6, 6]
# Epoch: 50
#
# Test set: Average loss: 0.203448
#
# Epoch: 100
#
# Test set: Average loss: 0.202664
#
# Epoch: 150
#
# Test set: Average loss: 0.204289
#
# Epoch: 200
#
# Test set: Average loss: 0.204557
#
# Epoch: 250
#
# Test set: Average loss: 0.205716
#
# Epoch: 300
#
# Test set: Average loss: 0.204979
#
# Epoch: 350
#
# Test set: Average loss: 0.210309
#
# Epoch: 400
#
# Test set: Average loss: 0.202426
#
# Epoch: 450
#
# Test set: Average loss: 0.199798
#
# Epoch: 500
#
# Test set: Average loss: 0.208353
#
# [6, 7, 3, 0.20835276448076956]
# [9, 9, 9]
# Epoch: 50
#
# Test set: Average loss: 0.140922
#
# Epoch: 100
#
# Test set: Average loss: 0.141718
#
# Epoch: 150
#
# Test set: Average loss: 0.140176
#
# Epoch: 200
#
# Test set: Average loss: 0.139682
#
# Epoch: 250
#
# Test set: Average loss: 0.142341
#
# Epoch: 300
#
# Test set: Average loss: 0.140800
#
# Epoch: 350
#
# Test set: Average loss: 0.137926
#
# Epoch: 400
#
# Test set: Average loss: 0.140090
#
# Epoch: 450
#
# Test set: Average loss: 0.139185
#
# Epoch: 500
#
# Test set: Average loss: 0.140217
#
# [9, 3, 3, 0.14021653580262358]
# [9, 9, 9, 9, 9]
# Epoch: 50
#
# Test set: Average loss: 0.271608
#
# Epoch: 100
#
# Test set: Average loss: 0.267769
#
# Epoch: 150
#
# Test set: Average loss: 0.270462
#
# Epoch: 200
#
# Test set: Average loss: 0.268624
#
# Epoch: 250
#
# Test set: Average loss: 0.269643
#
# Epoch: 300
#
# Test set: Average loss: 0.273667
#
# Epoch: 350
#
# Test set: Average loss: 0.268163
#
# Epoch: 400
#
# Test set: Average loss: 0.267593
#
# Epoch: 450
#
# Test set: Average loss: 0.270885
#
# Epoch: 500
#
# Test set: Average loss: 0.274416
#
# [9, 5, 3, 0.27441562471524916]
# [9, 9, 9, 9, 9, 9, 9]
# Epoch: 50
#
# Test set: Average loss: 0.133557
#
# Epoch: 100
#
# Test set: Average loss: 0.132364
#
# Epoch: 150
#
# Test set: Average loss: 0.133616
#
# Epoch: 200
#
# Test set: Average loss: 0.132841
#
# Epoch: 250
#
# Test set: Average loss: 0.131149
#
# Epoch: 300
#
# Test set: Average loss: 0.133282
#
# Epoch: 350
#
# Test set: Average loss: 0.132286
#
# Epoch: 400
#
# Test set: Average loss: 0.132530
#
# Epoch: 450
#
# Test set: Average loss: 0.134611
#
# Epoch: 500
#
# Test set: Average loss: 0.136297
#
# [9, 7, 3, 0.13629748571598935]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-2fff03aebc3c> in <module>
#      27             print(hyperparams[-1])
#      28
# ---> 29 pickle.dump(hyperparams, open('hyperparam_runs.pickle', 'wb'))
#
# NameError: name 'pickle' is not defined

# %%
import pickle 
pickle.dump(hyperparams, open('hyperparam_runs.pickle', 'wb'))

# %%
hyperparams
# Out:
# [[3, 3, 3, 1.1901369514374631],
#  [3, 5, 3, 0.2456078039523973],
#  [3, 7, 3, 0.5105965993993377],
#  [6, 3, 3, 0.11973414125472952],
#  [6, 5, 3, 0.5458264064765384],
#  [6, 7, 3, 0.20835276448076956],
#  [9, 3, 3, 0.14021653580262358],
#  [9, 5, 3, 0.27441562471524916],
#  [9, 7, 3, 0.13629748571598935]]

# %%
from statsmodels.tsa.arima_model import ARMA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-109-91bb9fade640> in <module>
# ----> 1 from statsmodels.tsa.arima_model import ARMA
#
# ModuleNotFoundError: No module named 'statsmodels'
